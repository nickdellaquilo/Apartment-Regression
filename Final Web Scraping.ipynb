# %%
from bs4 import BeautifulSoup
import os
import pandas as pd
import pickle
import random
import re
from selenium import webdriver
import time

# %%
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#scraping every apartment listing off of StreetEasy Brooklyn rentals

driver = webdriver.Chrome(chromedriver)
#listings = []

for page_num in range(int(len(listings)/11), 632):
    driver.get(f"https://streeteasy.com/for-rent/brooklyn?page={page_num}")
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    all_urls = soup.find_all('a', class_ = "listingCard-globalLink jsGlobalListingCardLink", attrs = "href")
    for u in all_urls:
        link = u.get("href")
        if link not in listings:
            listings.append(link)
    time.sleep(2.5 + (random.random() * 5.0))
    print("scraped page " + str(page_num))
    
driver.quit()
# Out:
# scraped page 577
# scraped page 578
# scraped page 579
# scraped page 580
# scraped page 581
# scraped page 582
# scraped page 583
# scraped page 584
# scraped page 585
# scraped page 586
# scraped page 587
# scraped page 588
# scraped page 589
# scraped page 590
# scraped page 591
# scraped page 592
# scraped page 593
# scraped page 594
# scraped page 595
# scraped page 596
# scraped page 597
# scraped page 598
# scraped page 599
# scraped page 600
# scraped page 601
# scraped page 602
# scraped page 603
# scraped page 604
# scraped page 605
# scraped page 606
# scraped page 607
# scraped page 608
# scraped page 609
# scraped page 610
# scraped page 611
# scraped page 612
# scraped page 613
# scraped page 614
# scraped page 615
# scraped page 616
# scraped page 617
# scraped page 618
# scraped page 619
# scraped page 620
# scraped page 621
# scraped page 622
# scraped page 623
# scraped page 624
# scraped page 625
# scraped page 626
# scraped page 627
# scraped page 628
# scraped page 629
# scraped page 630
# scraped page 631

# %%
print(len(listings))
print(listings)
# Out:
# 6347
# ['https://streeteasy.com/building/773-grand-street-brooklyn/4r', 'https://streeteasy.com/building/236-north-11-street-brooklyn/4aa', 'https://streeteasy.com/building/318-jefferson-street-brooklyn/rental/3514941', 'https://streeteasy.com/building/13-belvidere-street-brooklyn/2f', 'https://streeteasy.com/building/151-meserole-street-brooklyn/3f', 'https://streeteasy.com/building/412-evergreen-avenue-brooklyn/4g', 'https://streeteasy.com/building/292-clinton-street-brooklyn/1', 'https://streeteasy.com/building/750-washington-avenue-brooklyn/3fr', 'https://streeteasy.com/building/558-parkside-avenue-brooklyn/c5', 'https://streeteasy.com/building/366-hancock-street-brooklyn/4rd', 'https://streeteasy.com/building/412-evergreen-avenue-brooklyn/2a', 'https://streeteasy.com/building/level-2-north-6-place-brooklyn/6a', 'https://streeteasy.com/rental/3514850', 'https://streeteasy.com/building/566-parkside-avenue-brooklyn/b7', 'https://streeteasy.com/building/319-18-street-brooklyn/2a', 'https://streeteasy.com/building/the-rheingold/223', 'https://streeteasy.com/building/8701-shore-road-brooklyn/133', 'https://streeteasy.com/building/148-meserole-street-brooklyn/4r', 'https://streeteasy.com/building/234-skillman-avenue-brooklyn-2/rental/3514840', 'https://streeteasy.com/building/175-stockholm-street-brooklyn/105', 'https://streeteasy.com/building/1013-president-street-brooklyn/1', 'https://streeteasy.com/building/439-knickerbocker-avenue-brooklyn/2aa', 'https://streeteasy.com/building/231-jefferson-street-brooklyn/2lc', 'https://streeteasy.com/building/152-de-graw-street-brooklyn/3f', 'https://streeteasy.com/building/297-baltic-street-brooklyn/1', 'https://streeteasy.com/building/26-arion-place-brooklyn/1a', 'https://streeteasy.com/building/845-grand-street-brooklyn/6b', 'https://streeteasy.com/building/492-gates-avenue-brooklyn/4b', 'https://streeteasy.com/building/106-president-street-brooklyn/2', 'https://streeteasy.com/building/222-stanhope-street-brooklyn/3la', 'https://streeteasy.com/building/2702-kings-highway-brooklyn/a5', 'https://streeteasy.com/building/878-greene-avenue-brooklyn/3l', 'https://streeteasy.com/building/523-throop-avenue-brooklyn/2r', 'https://streeteasy.com/building/1154-gates-avenue-brooklyn/unit-2l', 'https://streeteasy.com/building/515-81-street-brooklyn/2', 'https://streeteasy.com/building/378-lewis-avenue-brooklyn/3', 'https://streeteasy.com/building/214-atlantic-avenue-brooklyn/2', 'https://streeteasy.com/building/1052-greene-avenue-brooklyn/410', 'https://streeteasy.com/building/3100-brighton-2-street-brooklyn/4', 'https://streeteasy.com/building/68-4-place-brooklyn/4l', 'https://streeteasy.com/building/1327-halsey-street-brooklyn/rental/3514786', 'https://streeteasy.com/building/13-jefferson-street-brooklyn/2a', 'https://streeteasy.com/building/674-jefferson-avenue-brooklyn/rental/3514784', 'https://streeteasy.com/building/1948-85-street-brooklyn/1b', 'https://streeteasy.com/building/324-clifton-place-brooklyn/2', 'https://streeteasy.com/building/365-columbia-street-brooklyn/2r', 'https://streeteasy.com/building/1117-lafayette-avenue-brooklyn/2r', 'https://streeteasy.com/building/184-clarkson-avenue-brooklyn/apartment-3a', 'https://streeteasy.com/building/378-lewis-avenue-brooklyn/8', 'https://streeteasy.com/building/171-starr-street-brooklyn/unit-3r', 'https://streeteasy.com/building/734-58-street-brooklyn/3e', 'https://streeteasy.com/building/189-meserole-avenue-brooklyn/1r', 'https://streeteasy.com/building/73-pineapple-street-brooklyn/3r', 'https://streeteasy.com/building/45-hawthorne-street-brooklyn/cc5', 'https://streeteasy.com/building/252-kingsland-avenue-brooklyn/3r', 'https://streeteasy.com/building/the-plex/4s', 'https://streeteasy.com/building/959-carroll-street-brooklyn/f10', 'https://streeteasy.com/building/1806-ocean-avenue-brooklyn/4b', 'https://streeteasy.com/building/214-atlantic-avenue-brooklyn/1', 'https://streeteasy.com/building/878-greene-avenue-brooklyn/4r', 'https://streeteasy.com/b ...

# %%
open_file = open("data/listing_urls.pickle", "wb")
pickle.dump(listings, open_file)
open_file.close()

# %%
open_file = open("data/listing_urls.pickle", "rb")
loaded_list = pickle.load(open_file)
open_file.close

print(len(loaded_list))
print(loaded_list)
# Out:
# 6347
# ['https://streeteasy.com/building/773-grand-street-brooklyn/4r', 'https://streeteasy.com/building/236-north-11-street-brooklyn/4aa', 'https://streeteasy.com/building/318-jefferson-street-brooklyn/rental/3514941', 'https://streeteasy.com/building/13-belvidere-street-brooklyn/2f', 'https://streeteasy.com/building/151-meserole-street-brooklyn/3f', 'https://streeteasy.com/building/412-evergreen-avenue-brooklyn/4g', 'https://streeteasy.com/building/292-clinton-street-brooklyn/1', 'https://streeteasy.com/building/750-washington-avenue-brooklyn/3fr', 'https://streeteasy.com/building/558-parkside-avenue-brooklyn/c5', 'https://streeteasy.com/building/366-hancock-street-brooklyn/4rd', 'https://streeteasy.com/building/412-evergreen-avenue-brooklyn/2a', 'https://streeteasy.com/building/level-2-north-6-place-brooklyn/6a', 'https://streeteasy.com/rental/3514850', 'https://streeteasy.com/building/566-parkside-avenue-brooklyn/b7', 'https://streeteasy.com/building/319-18-street-brooklyn/2a', 'https://streeteasy.com/building/the-rheingold/223', 'https://streeteasy.com/building/8701-shore-road-brooklyn/133', 'https://streeteasy.com/building/148-meserole-street-brooklyn/4r', 'https://streeteasy.com/building/234-skillman-avenue-brooklyn-2/rental/3514840', 'https://streeteasy.com/building/175-stockholm-street-brooklyn/105', 'https://streeteasy.com/building/1013-president-street-brooklyn/1', 'https://streeteasy.com/building/439-knickerbocker-avenue-brooklyn/2aa', 'https://streeteasy.com/building/231-jefferson-street-brooklyn/2lc', 'https://streeteasy.com/building/152-de-graw-street-brooklyn/3f', 'https://streeteasy.com/building/297-baltic-street-brooklyn/1', 'https://streeteasy.com/building/26-arion-place-brooklyn/1a', 'https://streeteasy.com/building/845-grand-street-brooklyn/6b', 'https://streeteasy.com/building/492-gates-avenue-brooklyn/4b', 'https://streeteasy.com/building/106-president-street-brooklyn/2', 'https://streeteasy.com/building/222-stanhope-street-brooklyn/3la', 'https://streeteasy.com/building/2702-kings-highway-brooklyn/a5', 'https://streeteasy.com/building/878-greene-avenue-brooklyn/3l', 'https://streeteasy.com/building/523-throop-avenue-brooklyn/2r', 'https://streeteasy.com/building/1154-gates-avenue-brooklyn/unit-2l', 'https://streeteasy.com/building/515-81-street-brooklyn/2', 'https://streeteasy.com/building/378-lewis-avenue-brooklyn/3', 'https://streeteasy.com/building/214-atlantic-avenue-brooklyn/2', 'https://streeteasy.com/building/1052-greene-avenue-brooklyn/410', 'https://streeteasy.com/building/3100-brighton-2-street-brooklyn/4', 'https://streeteasy.com/building/68-4-place-brooklyn/4l', 'https://streeteasy.com/building/1327-halsey-street-brooklyn/rental/3514786', 'https://streeteasy.com/building/13-jefferson-street-brooklyn/2a', 'https://streeteasy.com/building/674-jefferson-avenue-brooklyn/rental/3514784', 'https://streeteasy.com/building/1948-85-street-brooklyn/1b', 'https://streeteasy.com/building/324-clifton-place-brooklyn/2', 'https://streeteasy.com/building/365-columbia-street-brooklyn/2r', 'https://streeteasy.com/building/1117-lafayette-avenue-brooklyn/2r', 'https://streeteasy.com/building/184-clarkson-avenue-brooklyn/apartment-3a', 'https://streeteasy.com/building/378-lewis-avenue-brooklyn/8', 'https://streeteasy.com/building/171-starr-street-brooklyn/unit-3r', 'https://streeteasy.com/building/734-58-street-brooklyn/3e', 'https://streeteasy.com/building/189-meserole-avenue-brooklyn/1r', 'https://streeteasy.com/building/73-pineapple-street-brooklyn/3r', 'https://streeteasy.com/building/45-hawthorne-street-brooklyn/cc5', 'https://streeteasy.com/building/252-kingsland-avenue-brooklyn/3r', 'https://streeteasy.com/building/the-plex/4s', 'https://streeteasy.com/building/959-carroll-street-brooklyn/f10', 'https://streeteasy.com/building/1806-ocean-avenue-brooklyn/4b', 'https://streeteasy.com/building/214-atlantic-avenue-brooklyn/1', 'https://streeteasy.com/building/878-greene-avenue-brooklyn/4r', 'https://streeteasy.com/b ...

# %%
#size in bytes
os.stat("data/listing_urls.pickle").st_size
# Out:
# 404485

# %%
del f

# %%
#downloading each page


while(len(os.listdir("data/listings")) < len(loaded_list)):

    driver = webdriver.Chrome(chromedriver)

    #for l in loaded_list[:10]:
    start = len(os.listdir("data/listings")) + 1
    for i in range(start, len(loaded_list) + 1):
        driver.get(loaded_list[i])
        t = driver.title
        #time.sleep(2.5 + (random.random() * 5.0))
        #t = driver.title
        print("got: " + t)
        if not t:
            break # stop scraping if page fails to load
        open(f"/Users/nickdellaquilo/Documents/Metis/Apartment-Regression/data/listings/{t}.html", "x")
        with open(f"data/listings/{t}.html", "w") as f:
            f.write(driver.page_source)

        print("saved " + t)
        #time.sleep(2.5 + (random.random() * 5.0))

    driver.quit()
# Out:
# got: 1326 Ocean Avenue #5/J in Ditmas Park, Brooklyn | StreetEasy
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-109-b71e8993b802> in <module>
#      16         if not t:
#      17             break # stop scraping if page fails to load
# ---> 18         open(f"/Users/nickdellaquilo/Documents/Metis/Apartment-Regression/data/listings/{t}.html", "x")
#      19         with open(f"data/listings/{t}.html", "w") as f:
#      20             f.write(driver.page_source)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/nickdellaquilo/Documents/Metis/Apartment-Regression/data/listings/1326 Ocean Avenue #5/J in Ditmas Park, Brooklyn | StreetEasy.html'

# %%
print(len(os.listdir("data/listings")))
print(loaded_list[347])
# Out:
# 347
# https://streeteasy.com/building/93-4-avenue-brooklyn/3

# %%
test = open("data/test.txt", "w")
test.close()

# %%
os.getcwd()
# Out:
# '/Users/nickdellaquilo/Documents/Metis/Apartment-Regression'

# %%
#imports
from bs4 import BeautifulSoup
import requests
import time, os
import random

# %% [markdown]
# https://pypi.org/project/geopy/

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent = "Apartment-Regression")
location = geolocator.geocode("1656 Stillwell Ave, Brooklyn, NY 11223")
print(location.address)
print((location.latitude, location.longitude))
#print(location.raw)
# Out:
# 1656, Stillwell Avenue, Gravesend, Brooklyn, Kings County, New York, 11223, United States
# (40.60655673312856, -73.98723318726259)

# %%
scraping_url = "https://streeteasy.com/for-rent/brooklyn"
test_url = "https://streeteasy.com/building/556-court-street-brooklyn/2"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0"}
response = requests.get(test_url, headers = headers)
response.status_code
# Out:
# 403

# %%
page = response.text
soup = BeautifulSoup(page, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <style type="text/css">
#    input[type="submit"] {
#         margin: 43px 0 74px;
#         padding: 10px 16px;
#         line-height: 1.33;
#         font-size: 14px;
#         font-weight: 400;
#         text-transform: uppercase;
#         color: #FFF;
#         background: #555;
#         border: solid #555;
#         border-width: 0 0 2px 0;
#         border-radius: 2px;
#         transition: all 200ms;
#     }
#         table table {
#       width: 600px !important;
#     }
#     table div { /* logo */
#       width: 100%;
#       float: none;
#       text-align: center;
#     }
#     table div + div { /* main content */
#       width: 100%;
#       float: left;
#       text-align: left;
#     }
#     table div + div + div { /* trace */
#       width: 100%;
#       float: left;
#       text-align: left;
#     }
#     table div + div + div + div { /* footer */
#       width: 100%;
#       float: none;
#       clear: both;
#       text-align: left;
#     }
#     @media (max-width: 630px) {
#       table table {
#         width: 96% !important;
#       }
#       table div {
#         float: none !important;
#         width: 100% !important;
#       }
#     }
#     input[type="submit"] {
#     margin: 43px 0 74px;
#     padding: 10px 16px;
#     line-height: 1.33;
#     font-size: 14px;
#     font-weight: 400;
#     text-transform: uppercase;
#     color: #FFF;
#     background: #555;
#     border: solid #555;
#     border-width: 0 0 2px 0;
#     border-radius: 2px;
#     transition: all 200ms;
# }
#   </style>
#   <!-- Custom CSS -->
#  </head>
#  <body background="" style="margin: 0; padding: 0; font-family:Arial,FreeSans,sans-serif">
#   <table cellpadding="0" cellspacing="0" style="width: 100%; margin-top: 10px; margin-left: 0">
#    <tr>
#     <td style="padding: 12px 2%;">
#      <table cellpadding="0" cellspacing="0" style="margin: 0 auto; width: 96%;">
#       <tr>
#        <td style="padding: 12px 2%;">
#         <div>
#          <img src="http://streeteasy-public.s3.amazonaws.com/StreetEasy_logo_blue.png" width="450px"/>
#          <br/>
#          <br/>
#         </div>
#         <div>
#          <h2 style="margin-top: 0;">
#           Pardon Our Interruption
#          </h2>
#          <p>
#           As you were browsing, something about your browser
#         made us think you were a bot. There are a few reasons why this might happen:
#          </p>
#          <ul>
#           <li>
#            You're a power user moving through this website with super-human speed
#           </li>
#           <li>
#            You've disabled JavaScript in your web browser
#           </li>
#           <li>
#            A third-party browser plugin, such as Ghostery or NoScript, is preventing JavaScript from running.
#           Additional information is available in this
#            <a href="http://ds.tl/help-third-party-plugins" target="_blank" title="Third party browser plugins that block javascript">
#             support article.
#            </a>
#           </li>
#          </ul>
#          <p>
#           After completing the CAPTCHA below, you will immediately regain access to the site.
#          </p>
#         </div>
#         <div id="px-captcha">
#         </div>
#         <div>
#          <p>
#           Reference ID: #00676bb0-ac24-11eb-a743-cf76bc430113
#          </p>
#         </div>
#         <div style="border-top: solid 1px #ccc;">
#          <p style="font-size: 75%">
#           Contact us for assistance at
#           <a href="mailto:support@streeteasy.com">
#            support@streeteasy.com
#           </a>
#          </p>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <!-- Px -->
#   <script>
#    window._pxAppId = 'PXcZdhF737';
#     window._pxJsClientSrc = '/cZdhF737/init.js';
#     window._pxFirstPartyEnabled = true;
#     window._pxVid = '';
#     window._pxUuid = '00676bb0-ac24-11eb-a743-cf76bc430113';
#     window._pxHostUrl = '/cZdhF737/xhr';
#   </script>
#   <script>
#    var s = document.createElement('script');
#     s.src = '/cZdhF737/captcha/captcha.js?a=c&u=00676bb0-ac24-11eb-a743-cf76bc430113&v=&m=0';
#     var p = document.getElementsByTagName('head')[0];
#     p.insertBefore(s, null);
#     if (true) {
#         s.onerror = function () {
#             s = document.createElement('script');
#             var suffixIndex = '/cZdhF737/captcha/captcha.js?a=c&u=00676bb0-ac24-11eb-a743-cf76bc430113&v=&m=0'.indexOf('captcha.js');
#             var temperedBlockScript = '/cZdhF737/captcha/captcha.js?a=c&u=00676bb0-ac24-11eb-a743-cf76bc430113&v=&m=0'.substring(suffixIndex);
#             s.src = '//captcha.px-cdn.net/PXcZdhF737/' + temperedBlockScript;
#             p.parentNode.insertBefore(s, p);
#         };
#     }
#   </script>
#   <!-- Custom Script -->
#  </body>
# </html>

# %%
#need to use a fake user agent
from fake_useragent import UserAgent

ua = UserAgent()
user_agent = {'User-agent': ua.random}
print(user_agent)

response  = requests.get(test_url, headers = user_agent)
response.status_code
# Out:
# {'User-agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36'}
# 403

# %%
page = response.text
soup = BeautifulSoup(page, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <style type="text/css">
#    input[type="submit"] {
#         margin: 43px 0 74px;
#         padding: 10px 16px;
#         line-height: 1.33;
#         font-size: 14px;
#         font-weight: 400;
#         text-transform: uppercase;
#         color: #FFF;
#         background: #555;
#         border: solid #555;
#         border-width: 0 0 2px 0;
#         border-radius: 2px;
#         transition: all 200ms;
#     }
#         table table {
#       width: 600px !important;
#     }
#     table div { /* logo */
#       width: 100%;
#       float: none;
#       text-align: center;
#     }
#     table div + div { /* main content */
#       width: 100%;
#       float: left;
#       text-align: left;
#     }
#     table div + div + div { /* trace */
#       width: 100%;
#       float: left;
#       text-align: left;
#     }
#     table div + div + div + div { /* footer */
#       width: 100%;
#       float: none;
#       clear: both;
#       text-align: left;
#     }
#     @media (max-width: 630px) {
#       table table {
#         width: 96% !important;
#       }
#       table div {
#         float: none !important;
#         width: 100% !important;
#       }
#     }
#     input[type="submit"] {
#     margin: 43px 0 74px;
#     padding: 10px 16px;
#     line-height: 1.33;
#     font-size: 14px;
#     font-weight: 400;
#     text-transform: uppercase;
#     color: #FFF;
#     background: #555;
#     border: solid #555;
#     border-width: 0 0 2px 0;
#     border-radius: 2px;
#     transition: all 200ms;
# }
#   </style>
#   <!-- Custom CSS -->
#  </head>
#  <body background="" style="margin: 0; padding: 0; font-family:Arial,FreeSans,sans-serif">
#   <table cellpadding="0" cellspacing="0" style="width: 100%; margin-top: 10px; margin-left: 0">
#    <tr>
#     <td style="padding: 12px 2%;">
#      <table cellpadding="0" cellspacing="0" style="margin: 0 auto; width: 96%;">
#       <tr>
#        <td style="padding: 12px 2%;">
#         <div>
#          <img src="http://streeteasy-public.s3.amazonaws.com/StreetEasy_logo_blue.png" width="450px"/>
#          <br/>
#          <br/>
#         </div>
#         <div>
#          <h2 style="margin-top: 0;">
#           Pardon Our Interruption
#          </h2>
#          <p>
#           As you were browsing, something about your browser
#         made us think you were a bot. There are a few reasons why this might happen:
#          </p>
#          <ul>
#           <li>
#            You're a power user moving through this website with super-human speed
#           </li>
#           <li>
#            You've disabled JavaScript in your web browser
#           </li>
#           <li>
#            A third-party browser plugin, such as Ghostery or NoScript, is preventing JavaScript from running.
#           Additional information is available in this
#            <a href="http://ds.tl/help-third-party-plugins" target="_blank" title="Third party browser plugins that block javascript">
#             support article.
#            </a>
#           </li>
#          </ul>
#          <p>
#           After completing the CAPTCHA below, you will immediately regain access to the site.
#          </p>
#         </div>
#         <div id="px-captcha">
#         </div>
#         <div>
#          <p>
#           Reference ID: #17bc35b0-ac25-11eb-b6a1-d550889ee9a2
#          </p>
#         </div>
#         <div style="border-top: solid 1px #ccc;">
#          <p style="font-size: 75%">
#           Contact us for assistance at
#           <a href="mailto:support@streeteasy.com">
#            support@streeteasy.com
#           </a>
#          </p>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <!-- Px -->
#   <script>
#    window._pxAppId = 'PXcZdhF737';
#     window._pxJsClientSrc = '/cZdhF737/init.js';
#     window._pxFirstPartyEnabled = true;
#     window._pxVid = '';
#     window._pxUuid = '17bc35b0-ac25-11eb-b6a1-d550889ee9a2';
#     window._pxHostUrl = '/cZdhF737/xhr';
#   </script>
#   <script>
#    var s = document.createElement('script');
#     s.src = '/cZdhF737/captcha/captcha.js?a=c&u=17bc35b0-ac25-11eb-b6a1-d550889ee9a2&v=&m=0';
#     var p = document.getElementsByTagName('head')[0];
#     p.insertBefore(s, null);
#     if (true) {
#         s.onerror = function () {
#             s = document.createElement('script');
#             var suffixIndex = '/cZdhF737/captcha/captcha.js?a=c&u=17bc35b0-ac25-11eb-b6a1-d550889ee9a2&v=&m=0'.indexOf('captcha.js');
#             var temperedBlockScript = '/cZdhF737/captcha/captcha.js?a=c&u=17bc35b0-ac25-11eb-b6a1-d550889ee9a2&v=&m=0'.substring(suffixIndex);
#             s.src = '//captcha.px-cdn.net/PXcZdhF737/' + temperedBlockScript;
#             p.parentNode.insertBefore(s, p);
#         };
#     }
#   </script>
#   <!-- Custom Script -->
#  </body>
# </html>

# %%
#still won't work. need to use Selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(test_url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
print(soup.prettify())
# Out:
# <html lang="en-US" style="overflow-y: auto;" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:v="urn:schemas-microsoft-com:vml">
#  <head>
#   <style>
#    .gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}
#   </style>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans:400,500,700" rel="stylesheet" type="text/css"/>
#   <style>
#    .gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
#   </style>
#   <style>
#    .gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
#   </style>
#   <style>
#    @media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}
#   </style>
#   <style>
#    .gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}
#   </style>
#   <style>
#    .gm-style img{max-width: none;}.gm-style {font: 400 11px Roboto, Arial, sans-serif; text-decoration: none;}
#   </style>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/manifest-c93475b02bd2409b4a52e21af023e5d5f489f19500d234a3660fe4d35069bbac.json" rel="manifest"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=yes, minimal-ui" name="viewport"/>
#   <title>
#    556 Court Street #2 in Carroll Gardens, Brooklyn | StreetEasy
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=yes, shrink-to-fit=no" name="viewport"/>
#   <iframe data-gtm-yt-inspected-289328_644="true" src="about:blank" style="position: absolute; top: -10000px; left: -1000px;">
#   </iframe>
#   <script async="" id="www-widgetapi-script" src="https://www.youtube.com/s/player/bce81a70/www-widgetapi.vflset/www-widgetapi.js" type="text/javascript">
#   </script>
#   <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101">
#   </script>
#   <script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript">
#   </script>
#   <script async="" src="//s3.amazonaws.com/ki.js/51812/cvV.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.youtube.com/iframe_api" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" src="https://cdn5.userzoom.com/feedback/js/uz_feed_us.js?cuid=5FC691076FCDE41180C90050569444FB" type="text/javascript">
#   </script>
#   <script async="" src="//analytics.zg-api.com/a/s/js/v1/analytics.js">
#   </script>
#   <script async="" src="//bat.bing.com/bat.js">
#   </script>
#   <script async="" src="https://unpkg.com/web-vitals" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://sb.scorecardresearch.com/beacon.js">
#   </script>
#   <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-MKTT9R">
#   </script>
#   <script async="" src="/cZdhF737/init.js">
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script src="https://polyfill.io/v3/polyfill.min.js?features=Intl">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-O8HdAJg1h8RARFowXd2J/r5fIWuinSBtjhwQoPesfVILeXzGpJxvyY/77OaPPXUo" src="https://browser.sentry-cdn.com/5.20.1/bundle.min.js">
#   </script>
#   <script>
#    Sentry.init({
#       dsn: "https://ba99ce3a6378402f914e675bbc841300@o147001.ingest.sentry.io/1437971",
#       environment: "production",
#       release: "94b708890c378319a8da8f72763021c6df37bce1",
#       maxBreadcrumbs: 50,
#       sampleRate: 0.25
#     });
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/jquery-ec53ee8c24c7fab2742e063f925f508745b3d988eae5e09e307c27b6809ab018.js">
#   </script>
#   <link as="font" crossorigin="anonymous" href="//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-Bold-487f2e9da2ff0740755a5ef01dc15a2888b89537795895203a831b13b199d8bb.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-SemiBold-fc772b0188bc262494be9dc529c50893ae189110dfcad5a286512b737aef93b8.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-Regular-ecf76895be1cf9e8b3edb254030e9c9c1d8f3c2efc1f9dc7e04ceff29eccae9c.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-Light-7ec7f22119da3493aedefd66ffd30f0aaf4cf4aee42d8254638bcca5971c3568.woff2" rel="preload"/>
#   <style>
#    @font-face {
#   font-family: 'Source Sans Pro';
#   font-style: normal;
#   font-weight: 700;
#   src: local('Source Sans Pro Bold'), local('SourceSansPro-Bold'), url(//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-Bold-487f2e9da2ff0740755a5ef01dc15a2888b89537795895203a831b13b199d8bb.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
#
# @font-face {
#   font-family: 'Source Sans Pro';
#   font-style: normal;
#   font-weight: 600;
#   src: local('Source Sans Pro SemiBold'), local('SourceSansPro-SemiBold'), url(//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-SemiBold-fc772b0188bc262494be9dc529c50893ae189110dfcad5a286512b737aef93b8.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
#
# @font-face {
#   font-family: 'Source Sans Pro';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Source Sans Pro Regular'), local('SourceSansPro-Regular'), url(//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-Regular-ecf76895be1cf9e8b3edb254030e9c9c1d8f3c2efc1f9dc7e04ceff29eccae9c.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
#
# @font-face {
#   font-family: 'Source Sans Pro';
#   font-style: normal;
#   font-weight: 300;
#   src: local('Source Sans Pro Light'), local('SourceSansPro-Light'), url(//cdn-assets-s3.streeteasy.com/assets/SourceSansPro-Light-7ec7f22119da3493aedefd66ffd30f0aaf4cf4aee42d8254638bcca5971c3568.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
#   </style>
#   <!-- Impressions Tracking Config -->
#   <script async="" type="text/javascript">
#    var SE_Tracker = (function(host){
#     var now = new Date().getTime();
#     var cache = [];
#
#     function inCache(key){
#       for(var i in cache){
#         if(cache[i] == key){
#           return true;
#         }
#       }
#       return false;
#     }
#
#     function post(url, params, callback){
#       if(inCache(params.key)){
#         return false;
#       }
#
#       cache.push(params.key);
#
#       var request = new XMLHttpRequest();
#
#       request.withCredentials = true;
#       request.open('POST', url, true);
#       request.setRequestHeader('Content-Type', 'application/x-www-form-urlencoded; charset=UTF-8');
#
#       request.onload = callback;
#
#       request.onerror = function(xhr, status, err) {
#         console.error(xhr, status, err.toString());
#       };
#
#       var query_string = [];
#
#       for(var key in params){
#         query_string.push(key + '=' + encodeURIComponent(params[key]));
#       }
#
#       request.send(query_string.join('&'));
#     }
#     return {
#       push: function(key){
#         if(key){
#           new Image().src = ['//', host, '/in/', key, '?r=', now].join('');
#         }
#       },
#       track: function(params){
#         post('/api/v4/events/track', params);
#       },
#       durablePush: function(key) {
#         var deferred = $j.Deferred();
#
#         if(key) {
#           var image = new Image();
#           var resolve = function() {
#             deferred.resolve();
#           };
#
#           image.onload = resolve;
#           image.onerror = resolve;
#           image.src = ['//', host, '/in/', key, '?r=', now].join('');
#         } else {
#           deferred.resolve();
#         }
#
#         return deferred.promise();
#       },
#       cache_keys: cache
#     };
#   })('tracker-legacy.streeteasy.com');
#   </script>
#   <!-- Impressions Tracking Config -->
#   <script async="" src="//js-sec.indexww.com/ht/p/182276-243388387802730.js">
#   </script>
#   <script type="text/javascript">
#    var googletag = googletag || {};
#  googletag.cmd = googletag.cmd || [];
#  (function() {
#    var gads = document.createElement("script");
#    gads.async = true;
#    gads.type = "text/javascript";
#    var useSSL = "https:" == document.location.protocol;
#    gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#    var node =document.getElementsByTagName("script")[0];
#    node.parentNode.insertBefore(gads, node);
#   })();
#   </script>
#   <script async="" type="text/javascript">
#    var seUserTimingMarkMs;
#   window.clientProfiler = {
#     timingCategory: function (mark) {
#       return {
#         'search.rentals': 'RentalSearch',
#         'search.sales': 'SaleSearch',
#         'search.buildings': 'BuildingSearch',
#         'home.rentals': 'RentalsHome',
#         'home.sales': 'SalesHome',
#         'home.buildings': 'BuildingsHome',
#         'rental': 'RentalHdp',
#         'sale': 'SaleHdp',
#         'building': 'BuildingHdp',
#         'property': 'PropertyHdp',
#         'complex': 'ComplexHdp',
#         'closing': 'ClosingHdp'
#       }[mark.split('.').slice(0, -1).join('.').toLowerCase()]
#     },
#
#     timingLabel: function (mark) {
#       return {
#         'listingImageVisible': 'ListingThumb',
#         'locationsPopulated': 'Locations',
#         'searchButtonVisible': 'SearchButton',
#         'mainImageVisible': 'ListingImage'
#       }[mark.split('.').pop()]
#     },
#
#     setMark: function (name, prefix) {
#       if (typeof performance !== 'undefined' && 'mark' in performance && name && seUserTimingMarkMs == null) {
#         var normalizedPrefix = prefix || '';
#         var prefixedMarkName = normalizedPrefix + name;
#
#         performance.clearMarks(prefixedMarkName);
#         performance.mark(prefixedMarkName);
#         seUserTimingMarkMs = Math.round(performance.now());
#
#         if (typeof RProfiler === 'object') {
#           RProfiler.addInfo('indicator', 'i33394', seUserTimingMarkMs);
#         }
#
#         if (typeof ga !== 'dataLayer') {
#           dataLayer.push({
#             'event': 'timingMark',
#             'timingVar': prefixedMarkName,
#             'timingCategory': clientProfiler.timingCategory(prefixedMarkName),
#             'timingLabel': clientProfiler.timingLabel(prefixedMarkName),
#             'timingValue': Math.round(performance.now())
#           });
#         }
#       }
#     }
#   };
#   </script>
#   <!-- Load `web-vitals` using a classic script that sets the global `webVitals` object. -->
#   <script defer="" src="https://unpkg.com/web-vitals@0.2.2/dist/web-vitals.es5.umd.min.js">
#   </script>
#   <!-- Catchpoint RUM Script -->
#   <script async="async" src="//cdn-assets-s3.streeteasy.com/assets/catchpoint-3.1.2-37236bdb5902a2880b74cf41fd4e086b299cd8a17284d741a042fa2e9da63e2b.js">
#   </script>
#   <!-- Catchpoint Web Vitals Script -->
#   <script>
#    // Function to set indicator value based on the token.
#    function setIndicator({
#    name: t,
#    delta: e
#    }) {
#    var a = "CLS" == t ? "cls" : "FID" == t ?
#    "fid" : "LCP" == t ? "lcp" : null;
#    null != a &&
#    RProfiler.addInfo("indicator",a,parseFloat(parseFloat(e).toFixed(2)))
#    }
#    // Set Web Vital metrics on DOMContentLoaded event.
#    addEventListener("DOMContentLoaded", (function() {
#    webVitals.getCLS(setIndicator);
#    webVitals.getFID(setIndicator);
#    webVitals.getLCP(setIndicator)
#    }))
#   </script>
#   <script type="text/javascript">
#    (function(){
#       window._pxAppId = 'PXcZdhF737';
#       // Custom parameters
#       // window._pxParam1 = "<param1>";
#       var p = document.getElementsByTagName('script')[0],
#           s = document.createElement('script');
#       s.async = 1;
#       s.src = '/cZdhF737/init.js';
#       p.parentNode.insertBefore(s,p);
#     }());
#   </script>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/favicon/152-d67c986b097bf02722bfe945c9ba3c976e7b96793235446d4c5b88c3e79dc1ec.png" rel="apple-touch-icon" type="image/x-icon"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/favicon/76-682975806745b092466611d72c2a15454801db2a4dc55ee54cb49c86c09c6371.png" rel="apple-touch-icon" sizes="76x76" type="image/x-icon"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/favicon/120-c0cd58edd4d6d49d41ca133494e5957af5c62d37e3aa7c4922934c29f7028570.png" rel="apple-touch-icon" sizes="120x120" type="image/x-icon"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/favicon/152-d67c986b097bf02722bfe945c9ba3c976e7b96793235446d4c5b88c3e79dc1ec.png" rel="apple-touch-icon" sizes="152x152" type="image/x-icon"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/favicon/favicon-0fd96e05c49a1589fc58ca50c23b55a22977048acb51182337eed4d9a8f4310f.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="General" name="Rating"/>
#   <meta content="app-id=660363289" name="se-ios-app"/>
#   <meta content="qJqlO5mEO2tCALBAsjgwNeLSWDuHOzKBDvR3t7v-vck" name="google-site-verification"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/app-3d4edba88fb0e08f53ed75f0502a0cf1d6dc12c4fbbcc96763219cc3a57e26e2.css" media="all" rel="stylesheet"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/build/css/styles-cc741d7f.chunk.css" media="screen" rel="stylesheet"/>
#   <link href="https://streeteasy.com" rel="Home"/>
#   <link href="/meta/nyc_opensearch_plugin.xml" rel="search" title="StreetEasy" type="application/opensearchdescription+xml"/>
#   <link href="//cdn-assets-s3.streeteasy.com/assets/logos/streeteasy-logo-047ee8555ce9969603b367cf129c602e9e44ba0cad32e651c8c618cdc5d6eda4.png" rel="image_src"/>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <link href="https://streeteasy.com/building/556-court-street-brooklyn/2" rel="canonical"/>
#   <meta content="For Rent: 556 Court St. in Carroll Gardens" name="title"/>
#   <meta content="556 COURT STREET #2 is a rental unit in Carroll Gardens, Brooklyn priced at $2,800." name="description"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/52/425370052.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/46/425370046.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/63/425370063.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/69/425370069.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/1/425370101.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/91/425370091.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/44/425370044.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/82/425370082.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/87/425370087.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/3/425370103.jpg" name="image_src"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/11/425370111.jpg" name="image_src"/>
#   <meta content="For Rent: 556 Court St. in Carroll Gardens" property="og:title"/>
#   <meta content="556 COURT STREET #2 is a rental unit in Carroll Gardens, Brooklyn priced at $2,800." property="og:description"/>
#   <meta content="https://streeteasy.com/building/556-court-street-brooklyn/2" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="692257023" property="fb:admins"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/52/425370052.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/46/425370046.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/63/425370063.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/69/425370069.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/1/425370101.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/91/425370091.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/44/425370044.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/82/425370082.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/87/425370087.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/3/425370103.jpg" property="og:image"/>
#   <meta content="https://cdn-img-feed.streeteasy.com/nyc/image/11/425370111.jpg" property="og:image"/>
#   <meta content="40.6749201, -73.99977288" name="ICBM"/>
#   <meta content="40.6749201; -73.99977288" name="geo.position"/>
#   <meta content="556 Court Street in Carroll Gardens, Brooklyn, NY 11231" name="geo.placename"/>
#   <meta content="US-NY" name="geo.region"/>
#   <link href="ios-app://660363289/streeteasy/rental/3488524" rel="alternate"/>
#   <meta content="false" property="al:web:should_fallback"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="aZArSw+u0Arnb3cef42HNkaLYGJ/LB6W85AXJqHo9Nfy7OGeZrppbJ2+3y9nxD7SOCwOGMcLWFloEpqli9Cnkg==" name="csrf-token"/>
#   <script type="text/javascript">
#    window.addEventListener('load', () => {
#       const clientId = '147313643782-6g6eiu6pva3rofhad6e7csk4r701hbpf.apps.googleusercontent.com'
#       const source = 'HDP';
#
#       handleGoogleOneTap(clientId, source);
#     });
#   </script>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="//streeteasy.com" rel="dns-prefetch"/>
#   <link href="//cdn-assets3.streeteasy.com" rel="dns-prefetch"/>
#   <link href="//cdn-img-feed.streeteasy.com" rel="dns-prefetch"/>
#   <link href="//tracker-legacy.streeteasy.com" rel="dns-prefetch"/>
#   <link href="//s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="//api.streeteasy.com" rel="dns-prefetch"/>
#   <link href="//bam.nr-data.net" rel="dns-prefetch"/>
#   <link href="//api.mapbox.com" rel="dns-prefetch"/>
#   <script async="async" type="application/ld+json">
#    //<![CDATA[
# [{"@context":"http://schema.org","@type":"Apartment","address":"556 Court Street","amenityFeature":[{"name":"Hardwood Floors","value":true}],"photo":{"@type":"ImageObject","contentUrl":"https://cdn-img-feed.streeteasy.com/nyc/image/52/425370052.jpg"},"description":"The shining hardwood floors have just been refinished, brand new appliances have been installed, a fully renovated brand new bathroom has been installed, all of the doors have been replaced, all new light fixtures, freshly painted! Closets in all of the bedrooms!\n\nThis bright 3 bedroom in a great location is the best deal in town","numberOfRooms":3.0}]
# //]]>
#   </script>
#   <script async="async" type="application/ld+json">
#    //<![CDATA[
# [{"@context":"http://schema.org","@type":"ItemPage","about":{"@type":"Product","name":"556 Court Street","offers":{"@type":"Offer","price":"2800.00","priceCurrency":"USD","availability":"inStock","url":"https://streeteasy.com/building/556-court-street-brooklyn/2"},"brand":"H L Dynasty Real Estate Corp","description":"The shining hardwood floors have just been refinished, brand new appliances have been installed, a fully renovated brand new bathroom has been installed, all of the doors have been replaced, all new light fixtures, freshly painted! Closets in all of the bedrooms!\n\nThis bright 3 bedroom in a great location is the best deal in town","image":"https://cdn-img-feed.streeteasy.com/nyc/image/52/425370052.jpg"},"mainEntity":{"@type":"Apartment","address":{"@type":"PostalAddress","addressRegion":"NY","addressLocality":"Brooklyn","streetAddress":"556 Court Street","postalCode":"11231","addressCountry":{"@type":"Country","name":"USA"}},"amenityFeature":[{"name":"Hardwood Floors","value":true}],"event":[]}}]
# //]]>
#   </script>
#   <script>
#    //<![CDATA[
# window.gon={};gon.graphql_endpoint="https://api-internal.streeteasy.com/graphql";gon.image_metadata_endpoint="https://kong.streeteasy.com/image_metadata/api/v1/image_metadata";gon.ua_is_mobile=false;gon.site_transportation=["1","2","3","4","5","6","7","A","C","E","B","D","F","M","J","Z","N","Q","R","W","G","L","S","PATH","HBLR"];gon.user_info={"user_logged_in":false,"user_id":null,"is_agent":null};gon.state={};
# //]]>
#   </script>
#   <style id="googleidentityservice_button_styles">
#    .qJTHM{-webkit-user-select:none;color:#202124;direction:ltr;-webkit-touch-callout:none;font-family:'Roboto-Regular',arial,sans-serif;-webkit-font-smoothing:antialiased;font-weight:400;margin:0;overflow:hidden;-webkit-text-size-adjust:100%}.ynRLnc{left:-9999px;position:absolute;top:-9999px}.L6cTce{display:none}.bltWBb{word-break:break-all}.hSRGPd{color:#1a73e8;cursor:pointer;font-weight:500;text-decoration:none}.Bz112c-W3lGp{height:16px;width:16px}.Bz112c-E3DyYd{height:20px;width:20px}.Bz112c-r9oPif{height:24px;width:24px}.Bz112c-uaxL4e{-webkit-border-radius:10px;border-radius:10px}.LgbsSe-Bz112c{display:block}.S9gUrf-YoZ4jf,.S9gUrf-YoZ4jf *{border:none;margin:0;padding:0}.fFW7wc-ibnC6b>.aZ2wEe>div{border-color:#4285f4}.P1ekSe-ZMv3u>div:nth-child(1){background-color:#1a73e8!important}.P1ekSe-ZMv3u>div:nth-child(2),.P1ekSe-ZMv3u>div:nth-child(3){background-image:linear-gradient(to right,rgba(255,255,255,0.7),rgba(255,255,255,0.7)),linear-gradient(to right,#1a73e8,#1a73e8)!important}.haAclf{display:inline-block}.nsm7Bb-HzV7m-LgbsSe{-webkit-border-radius:4px;border-radius:4px;-webkit-box-sizing:border-box;box-sizing:border-box;-webkit-transition:background-color .218s,border-color .218s;transition:background-color .218s,border-color .218s;-webkit-user-select:none;-webkit-appearance:none;background-color:#fff;background-image:none;border:1px solid #dadce0;color:#3c4043;cursor:pointer;font-family:'Google Sans',arial,sans-serif;font-size:14px;height:40px;letter-spacing:.25px;outline:none;overflow:hidden;padding:0 12px;position:relative;text-align:center;vertical-align:middle;white-space:nowrap;width:auto}@media screen and (-ms-high-contrast:active){.nsm7Bb-HzV7m-LgbsSe{border:2px solid windowText;color:windowText}}.nsm7Bb-HzV7m-LgbsSe.pSzOP-SxQuSe{font-size:14px;height:32px;letter-spacing:.25px;padding:0 10px}.nsm7Bb-HzV7m-LgbsSe.purZT-SxQuSe{font-size:11px;height:20px;letter-spacing:.3px;padding:0 8px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe{padding:0;width:40px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.pSzOP-SxQuSe{width:32px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.purZT-SxQuSe{width:20px}.nsm7Bb-HzV7m-LgbsSe.JGcpL-RbRzK{-webkit-border-radius:20px;border-radius:20px}.nsm7Bb-HzV7m-LgbsSe.JGcpL-RbRzK.pSzOP-SxQuSe{-webkit-border-radius:16px;border-radius:16px}.nsm7Bb-HzV7m-LgbsSe.JGcpL-RbRzK.purZT-SxQuSe{-webkit-border-radius:10px;border-radius:10px}.nsm7Bb-HzV7m-LgbsSe.MFS4be-Ia7Qfc{border:none;color:#fff}.nsm7Bb-HzV7m-LgbsSe.MFS4be-v3pZbf-Ia7Qfc{background-color:#1a73e8}.nsm7Bb-HzV7m-LgbsSe.MFS4be-JaPV2b-Ia7Qfc{background-color:#202124;color:#e8eaed}.nsm7Bb-HzV7m-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{height:18px;margin-right:8px;min-width:18px;width:18px}.nsm7Bb-HzV7m-LgbsSe.pSzOP-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{height:14px;min-width:14px;width:14px}.nsm7Bb-HzV7m-LgbsSe.purZT-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{height:10px;min-width:10px;width:10px}.nsm7Bb-HzV7m-LgbsSe.jVeSEe .nsm7Bb-HzV7m-LgbsSe-Bz112c{margin-left:8px;margin-right:-4px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{margin:0;padding:10px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.pSzOP-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{padding:8px}.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe.purZT-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c{padding:4px}.nsm7Bb-HzV7m-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf{-webkit-border-top-left-radius:3px;border-top-left-radius:3px;-webkit-border-bottom-left-radius:3px;border-bottom-left-radius:3px;display:-webkit-box;display:-webkit-flex;display:flex;justify-content:center;-webkit-align-items:center;align-items:center;background-color:#fff;height:36px;margin-left:-10px;margin-right:12px;min-width:36px;width:36px}.nsm7Bb-HzV7m-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf .nsm7Bb-HzV7m-LgbsSe-Bz112c,.nsm7Bb-HzV7m-LgbsSe.Bz112c-LgbsSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf .nsm7Bb-HzV7m-LgbsSe-Bz112c{margin:0;padding:0}.nsm7Bb-HzV7m-LgbsSe.pSzOP-SxQuSe .nsm7Bb-HzV7m-LgbsSe-Bz112c-haAclf{height:28px;margin-left:-8px;margin-right:10px;min-width:28px;width:28px}.nsm7Bb-HzV7m-LgbsSe.p ...
# /*# sourceURL=/_/gsi/_/ss/k=gsi.gsi.8f_g74g6J2c.L.W.O/am=cg/d=1/rs=AF0KOtU83mo9n97G1sqynMoELaVl9x_85Q/m=gis_client_button_style */
#   </style>
#   <meta content="A+b/H0b8RPXNaJgaNFpO0YOFuGK6myDQXlwnJB3SwzvNMfcndat4DZYMrP4ClJIzYWo3/yP2S+8FTZ/lpqbPAAEAAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2MjYyMjA3OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="A7+rMYR5onPnACrz+niKSeFdH3xw1IyHo2AZSHmxrofRk9w4HcQPMYcpBUKu6OQ6zsdxf4m/vqa6tG6Na4OLpAQAAAB4eyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiQ29udmVyc2lvbk1lYXN1cmVtZW50IiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1RoaXJkUGFydHkiOnRydWV9" http-equiv="origin-trial"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2021042801.js">
#   </script>
#   <style data-styled="active" data-styled-version="5.2.1">
#   </style>
#   <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAVUnDmuS8MwdAY8k-FEqiJZi1PaJ5c7b8&amp;v=3.42">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/common.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/util.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/map.js" type="text/javascript">
#   </script>
#   <link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=streeteasy.com" rel="preload"/>
#   <script src="https://adservice.google.com/adsid/integrator.js?domain=streeteasy.com" type="text/javascript">
#   </script>
#   <link href="https://071df6f432e640ebcc1d5e42c85e02eb.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" rel="prefetch"/>
#   <link href="https://tpc.googlesyndication.com/safeframe/1-0-38/html/container.html" rel="prefetch"/>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/969911984/?random=1620058761829&amp;cv=9&amp;fst=1620058761829&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=2505059651&amp;u_h=900&amp;u_w=1440&amp;u_ah=821&amp;u_aw=1440&amp;u_cd=24&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg4l3&amp;sendb=1&amp;ig=1&amp;data=listing_type%3Drental%3Blisting_price%3D2800%3Blisting_no_fee%3Dtrue%3Buser_type%3Danonymous&amp;frm=0&amp;url=https%3A%2F%2Fstreeteasy.com%2Fbuilding%2F556-court-street-brooklyn%2F2&amp;tiba=556%20Court%20Street%20%232%20in%20Carroll%20Gardens%2C%20Brooklyn%20%7C%20StreetEasy&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <meta content="" http-equiv="origin-trial"/>
#   <script src="https://www.googleadservices.com/pagead/conversion/959939665/?random=1620058761836&amp;cv=9&amp;fst=1620058761836&amp;num=1&amp;value=0&amp;label=C-NqCMbGzVYQ0YjeyQM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=2505059650&amp;u_h=900&amp;u_w=1440&amp;u_ah=821&amp;u_aw=1440&amp;u_cd=24&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg4l3&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fstreeteasy.com%2Fbuilding%2F556-court-street-brooklyn%2F2&amp;tiba=556%20Court%20Street%20%232%20in%20Carroll%20Gardens%2C%20Brooklyn%20%7C%20StreetEasy&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://www.googleadservices.com/pagead/conversion/951077172/?random=1620058761850&amp;cv=9&amp;fst=1620058761850&amp;num=1&amp;value=0&amp;label=5EqBCKLp52QQtJLBxQM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=2505059650&amp;u_h=900&amp;u_w=1440&amp;u_ah=821&amp;u_aw=1440&amp;u_cd=24&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg4l3&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fstreeteasy.com%2Fbuilding%2F556-court-street-brooklyn%2F2&amp;tiba=556%20Court%20Street%20%232%20in%20Carroll%20Gardens%2C%20Brooklyn%20%7C%20StreetEasy&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script async="" src="https://bat.bing.com/p/action/4017789" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/stats.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/onion.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/overlay.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/42/9a/controls.js" type="text/javascript">
#   </script>
#   <style id="qual_style-nfh" type="text/css">
#   </style>
#   <style id="qual_style-nat" type="text/css">
#   </style>
#   <link href="https://accounts.google.com/gsi/style" id="googleidentityservice" media="all" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="macintosh_platform webkit_engine chrome_browser desktop site_nyc rental" id="application">
#   <a class="SkipNavLink" href="#site-content">
#    Skip Navigation
#   </a>
#   <!-- START Google TagManager -->
#   <script defer="">
#    var slot_rtt_main_p1;var slot_amn_main_p1;var slot_amn_main_p2;var slot_amn_main_p3;var slot_b_right_p1;
#         googletag.cmd.push(function() {
#
#           slot_rtt_main_p1 = googletag.defineSlot('/7449/Streeteasy/property_details/rent_general/rtt_main_p1', ["fluid", [109, 25]], 'rtt_main_p1').addService(googletag.pubads());slot_amn_main_p1 = googletag.defineSlot('/7449/Streeteasy/property_details/rent_general/amn_main_p1', ["fluid", [574, 80]], 'amn_main_p1').addService(googletag.pubads());slot_amn_main_p2 = googletag.defineSlot('/7449/Streeteasy/property_details/rent_general/amn_main_p2', ["fluid", [574, 80]], 'amn_main_p2').addService(googletag.pubads());slot_amn_main_p3 = googletag.defineSlot('/7449/Streeteasy/property_details/rent_general/amn_main_p3', ["fluid", [574, 80]], 'amn_main_p3').addService(googletag.pubads());slot_b_right_p1 = googletag.defineSlot('/7449/Streeteasy/property_details/rent_general/b_right_p1', ["fluid", []], 'b_right_p1').addService(googletag.pubads());
#           googletag.pubads().setTargeting('dma', "43");
# googletag.pubads().setTargeting('env', "prod");
# googletag.pubads().setTargeting('pis', "1");
# googletag.pubads().setTargeting('listtp', "rent_general");
# googletag.pubads().setTargeting('bd', "3");
# googletag.pubads().setTargeting('sqft', "1100");
# googletag.pubads().setTargeting('sqftrange', "1000-1249");
# googletag.pubads().setTargeting('bldgid', "53110");
# googletag.pubads().setTargeting('proptp', "");
# googletag.pubads().setTargeting('price', "2800");
# googletag.pubads().setTargeting('yrblt', "1920-1939");
# googletag.pubads().setTargeting('brokerage', "h_l_dynasty_real_estate_corp");
# googletag.pubads().setTargeting('brokerfee', "no");
# googletag.pubads().setTargeting('prange', "2500-2999");
# googletag.pubads().setTargeting('aamgnrc1', "556 Court Street");
# googletag.pubads().setTargeting('aamgnrc2', "2");
# googletag.pubads().setTargeting('state', "ny");
# googletag.pubads().setTargeting('zip', "11231");
# googletag.pubads().setTargeting('boro', "brooklyn");
# googletag.pubads().setTargeting('hood', "carroll_gardens");
# googletag.pubads().setTargeting('cnty', "kings");
# googletag.pubads().setTargeting('city', "brooklyn");
# googletag.pubads().setTargeting('zguidh', "24974462208365782629729437543364983157382948749575637735908");
# googletag.pubads().setTargeting('amenities', ["hardwood_floors","nyc_evacuation_4"]);
#
#         [].slice.call(document.querySelectorAll('[data-dfp-key]')).forEach(function(el) {
#           var trackingKey = el.dataset.dfpKey,
#               trackingValue = el.dataset.dfpValue;
#
#           googletag.pubads().setTargeting(trackingKey, trackingValue);
#         })
#
#
#         function forceEagerLoadingOnAds(event) {
#           var domId = event.slot.getSlotId().getDomId();
#           var element = document.getElementById(domId);
#
#           if (!element) {
#             return;
#           }
#
#           var iframe = element.getElementsByTagName("iframe")[0];
#
#           if (!iframe) {
#             return;
#           }
#
#           iframe.setAttribute("loading", "eager");
#         }
#         googletag.pubads().addEventListener("slotRenderEnded", forceEagerLoadingOnAds);
#
#           googletag.pubads().setTargeting('page_type', 'property_details');
#           googletag.pubads().setTargeting('vers', 'tall');
#           googletag.pubads().enableSingleRequest()
#           googletag.pubads().collapseEmptyDivs();
#           googletag.enableServices();
#         });
#   </script>
#   <script type="text/javascript">
#    dataLayer = [{"zguidh":"24974462208365782629729437543364983157382948749575637735908","site":"nyc","userType":"anonymous","pageCat":"rentals","pageType":"show","listType":"rental","listID":3488524,"listPrice":2800,"listBoro":"brooklyn","listNabe":"carroll-gardens","listZip":"11231","listPropertyType":"rental","listStatus":"current","listDaysMarket":17,"listAgent":"Cole Borg|Humberto Lopes","listBrokerage":"h_l_dynasty_real_estate_corp","listAmen":"hardwood_floors|nyc_evacuation_4","listBuilding":53110,"listNoFee":true,"listAvailDate":"2021-04-16T12:34:19-04:00","listSqFt":1100,"listPPSF":2,"listBed":3,"listBath":1.0,"listRoom":6.0,"listPhotos":11,"listVideo":1,"listOpenHouse":0,"listDate":"2021-04-16","listGeoLat":40.6749201,"listGeoLon":-73.99977288,"session_q_c":0,"cookie_q_c":0}];
#   </script>
#   <!-- END Google TagManager -->
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MKTT9R" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#               new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-MKTT9R');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div class="SiteBlock" id="site-wrapper">
#    <div class="hidden-md" id="banner-spacer">
#    </div>
#    <div class="SiteBlock-canvas" id="site-canvas">
#     <div class="SiteBlock-shadow" id="site-shadow">
#     </div>
#     <header class="HeaderBlock jsHeader">
#      <div class="Header jsHeader">
#       <a class="MenuMobileButton MenuMobileButton--hideDesktop u-noBorder u-noMargin" data-toggle="menu" href="#">
#        <span class="MenuMobileButton-icon">
#        </span>
#       </a>
#       <div class="Container">
#        <div class="Header-logoDesktop">
#         <a class="Logo" href="/">
#          <img alt="StreetEasy Logo" class="Logo-image" src="//cdn-assets-s3.streeteasy.com/assets/logos/streeteasy-logo-white-1ab418223836c9074eb6f68857ad68a697eb31d2c86a98e597a467a7e527ac94.svg"/>
#         </a>
#        </div>
#        <div class="Header-mWebBox jsMobileNavbar">
#         <nav class="navbar navbar-default visible-xs-block visible-sm-block navbar-fixed-top jsMobileNavbar u-width--full">
#          <div class="container-fluid hide-print">
#           <div class="Logo">
#            <a href="/">
#             <img alt="StreetEasy Logo" class="Logo-image" src="//cdn-assets-s3.streeteasy.com/assets/logos/streeteasy-logo-white-1ab418223836c9074eb6f68857ad68a697eb31d2c86a98e597a467a7e527ac94.svg"/>
#            </a>
#           </div>
#          </div>
#         </nav>
#        </div>
#        <ul class="Header-nav">
#         <li class="Header-navListItem">
#          <a class="Header-navText" href="https://streeteasy.com/agent-resources/advertise/">
#           Advertise
#          </a>
#         </li>
#         <li class="Header-navListItem">
#          <button class="Header-navText u-font-baseSize jsGoogleOneTap" onclick="window.gon.state.analyticsData = {'source':'nav'}; window.gon.state.triggerScenario('');">
#           Sign In / Register
#          </button>
#         </li>
#        </ul>
#       </div>
#       <div id="stickyContainer">
#        <div class="styled__Container-sc-4v3d8h-0 bfQnzH">
#         <div class="styled__StickyDesktopContainer-n6g6fk-7 dQXzlT">
#          <div class="styled__ListingInformation-n6g6fk-2 iqrNWi">
#           <a class="styled__Link-o2bgiv-0 styled__whaleGrey-o2bgiv-8 ikZAft bsoFfv styled__BuildingLink-n6g6fk-0 kvBubo" href="/building/556-court-street-brooklyn">
#            556 Court Street #2
#           </a>
#           <div class="styled__Dot-n6g6fk-1 diCWfg">
#           </div>
#           <p class="Text-sc-1bcfnr7-0 styled__MediumListingText-n6g6fk-3 dxdgsT kRfFXr" type="default">
#            $2,800
#           </p>
#           <div class="styled__RoomInformation-n6g6fk-4 iMqCER">
#            <p class="Text-sc-1bcfnr7-0 styled__SmallListingText-n6g6fk-5 hxunBO kzsA-du" type="sm">
#             6 rooms
#            </p>
#            <p class="Text-sc-1bcfnr7-0 styled__SmallListingText-n6g6fk-5 hxunBO kzsA-du" type="sm">
#             3 beds
#            </p>
#            <p class="Text-sc-1bcfnr7-0 styled__SmallListingText-n6g6fk-5 hxunBO kJTnLa" type="sm">
#             1 bath
#            </p>
#           </div>
#          </div>
#          <div class="styled__StickyButtonSection-n6g6fk-6 cNEwTU">
#           <div class="styled__ButtonsContainer-sc-1nvoegm-2 ipDOUK">
#            <button class="styled__Button-sc-1d5hope-0 ddtYGo styled__ContactButton-sc-1nvoegm-0 styled__PrimaryContactButton-sc-1nvoegm-3 iFEpWc eTgfsf">
#             Request a tour
#            </button>
#            <button class="styled__Button-sc-1d5hope-0 iDvLFg styled__ContactButton-sc-1nvoegm-0 styled__SecondaryContactButton-sc-1nvoegm-1 iFEpWc ccQnHf">
#             Ask a question
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <script type="text/javascript">
#       window.addEventListener('load', () => {
#       const clientId = '147313643782-6g6eiu6pva3rofhad6e7csk4r701hbpf.apps.googleusercontent.com';
#       const loginButton = document.querySelectorAll('.jsGoogleOneTap');
#       const saveItemButtons = document.querySelectorAll('.saveItemAfterAuthentication');
#
#       loginButton.forEach(button => {
#         button.addEventListener('click', () => {
#           handleGoogleOneTap(clientId, 'nav');
#         })
#       });
#
#       saveItemButtons.forEach(button => {
#         button.addEventListener('click', () => {
#           handleGoogleOneTapOnSave(clientId, 'save');
#         });
#       });
#     });
#      </script>
#      <div class="SiteBlock-menu" id="site-menu">
#       <div class="MainNav">
#        <div class="Container">
#         <ul class="MainNav-list isHoverable">
#          <li class="MainNav-listItem isTrackingMenuItem" data-trending-id="3508200" data-type="Rentals">
#           <a class="MainNav-text" data-toggle="nav_popup" href="/rentals">
#            Rent
#           </a>
#           <div class="MainNav-popup">
#            <div class="Container">
#             <div class="MainNav-popupColumn">
#              <h6 class="Title Title--secondarySmCaps u-color-textSecondary u-noMargin">
#               Areas
#              </h6>
#              <ul class="MainNav-popupList">
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/manhattan">
#                 Manhattan
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/brooklyn">
#                 Brooklyn
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/queens">
#                 Queens
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/bronx">
#                 Bronx
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/staten-island">
#                 Staten Island
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/new-jersey">
#                 New Jersey
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/nyc">
#                 All NYC + NJ
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/apartments-for-rent-near-me">
#                 Near Me
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="MainNav-popupColumn MainNav-popupColumn--last">
#              <h6 class="Title Title--secondarySmCaps u-color-textSecondary u-noMargin">
#               Popular neighborhoods
#              </h6>
#              <ul class="MainNav-popupList">
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/tribeca">
#                 Tribeca
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/upper-east-side">
#                 Upper East Side
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/upper-west-side">
#                 Upper West Side
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/east-village">
#                 East Village
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/williamsburg">
#                 Williamsburg
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/astoria">
#                 Astoria
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/hoboken">
#                 Hoboken
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/for-rent/jersey-city">
#                 Jersey City
#                </a>
#               </li>
#               <li class="MainNav-popupListItem">
#                <a class="MainNav-popupColumnLink" data-gtm-header-menu="Rentals" href="/rentals/all">
#                 View All
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="MainNav-popupColumn MainNav-popupColumn--ads">
#              <div class="MostViewedItem">
#               <div class="MostViewedItem-imgBox">
#                <a data-gtm-header-listing-id="3508200" data-gtm-header-listing-type="rental" href="/building/the-grand-chelsea/6f">
#                 <img alt="270 West 17th Street" class="MostViewedItem-img" src="https://cdn-img-feed.streeteasy.com/nyc/image/44/427196344.jpg"/>
#                </a>
#               </div>
#               <div class="MostViewedItem-content">
#                <a class="MostViewedItem-titleLink" data-gtm-header-listing-id="3508200" data-gtm-header-listing-type="rental" href="/building/the-grand-chelsea/6f">
#                 270 West 17th Street
#                </a>
#                <div>
# ...
#       </a>
#       <a class="Footer-linkIcon" href="https://www.instagram.com/streeteasy/">
#        <img alt="Streeteasy instagram" class="Footer-icon Footer-icon--withoutMargin" src="//cdn-assets-s3.streeteasy.com/assets/icons/instagram-3441573dd0ddbbe8af00ab6ef4d499cd7faf5f1969d99eca9f039d735edf4059.png" srcset="//cdn-assets-s3.streeteasy.com/assets/icons/instagram@2x-cd1101d6c8d8a3998260937391c392ba0f2e283d66a5f0ad9f4eb9470bd0f47d.png 2x"/>
#       </a>
#      </div>
#      <div class="u-width--full u-text--alignCenter">
#       <div class="Footer-text Footer-text--brokerage">
#        StreetEasy is a brand and registered trademark of Zillow,
#               Inc. Zillow, Inc. has a real estate
#               brokerage license in multiple states. A list of these real estate licenses can be found
#        <a class="" href="https://www.zillow.com/info/real-estate-licenses/" rel="noopener noreferrer" target="_blank">
#         here
#        </a>
#        .
#       </div>
#      </div>
#      <div class="Footer-zgBrands">
#       <a class="Footer-text Footer-text--large Footer-text--zgBrand" href="https://www.zillow.com/">
#        Zillow
#       </a>
#       <span class="Footer-dot Footer-dot--zgBrands hidden-xs hidden-sm">
#        ·
#       </span>
#       <a class="Footer-text Footer-text--large Footer-text--zgBrand" href="https://www.trulia.com/">
#        Trulia
#       </a>
#       <span class="Footer-dot Footer-dot--zgBrands hidden-xs hidden-sm">
#        ·
#       </span>
#       <a class="Footer-text Footer-text--large Footer-text--zgBrand" href="https://hotpads.com/">
#        Hotpads
#       </a>
#       <span class="Footer-dot Footer-dot--zgBrands hidden-xs hidden-sm">
#        ·
#       </span>
#       <a class="Footer-text Footer-text--large Footer-text--zgBrand" href="https://outeast.com">
#        Out East
#       </a>
#      </div>
#      <div class="Footer-text hidden-md">
#       Zillow Inc. Sites © 2006-2021 Zillow
#      </div>
#      <div class="Footer-copyright hidden-xs hidden-sm">
#       <span class="Footer-text">
#        Zillow Inc. Sites © 2006-2021 Zillow
#        <span class="Footer-dot">
#         ·
#        </span>
#        <span class="only-print">
#         <b>
#          https://streeteasy.com/
#         </b>
#        </span>
#        <a class="Footer-text" href="http://nytm.org/made" rel="nofollow">
#         Made In NYC
#        </a>
#        <span class="Footer-dot">
#         ·
#        </span>
#        Powered by Bikes, Coffee and Doughnuts.
#       </span>
#      </div>
#      <div class="u-width--full">
#       <img alt="Footer Image" class="Footer-image" src="//cdn-assets-s3.streeteasy.com/assets/svg/footer-f3b296bd4be445e92b2d0fd4b1d3c1050d30933b14e76d7b2fcf8215bb01ba1a.svg"/>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/shared_hdp_bdp-05df96060effe7596f7dbc1c9db7ed418fe532b96fbcf37d68641fc249e17a9f.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/hdp-accf44a206d363163e3a0fa9f7dd6cd99a38331f9af3e3fee2b58cbe19ad9698.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/desktop-2d5b611857b30834cd18127c259f74ebc5295dad50dc809fec3608e494248dca.js">
#   </script>
#   <script>
#    (function (root) {
#           root.SEDeviceType = 'desktop';
#         }(window));
#   </script>
#   <script debug="false" src="//cdn-assets-s3.streeteasy.com/assets/pages/listing/analytics-9bc22d915626ec48da5a1aa7e5e57f29a40c086df0a7260b8d422be5c1e033ef.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/pages/buildings/flickity_init-2f85ea8622ff32fcc718f3f13cdf9911454c55ce0dcab7efe6e8f593f0267825.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/scripts/dynamic/dynamic_open_houses-07bbab0e4aeb7a4c83a9380f1c4a3fde574e23a977bfebfbbe3a8d68a9e542f5.js">
#   </script>
#   <div class="share-item" is-agent="" item-address="556 Court Street #2" item-area="Rental Unit in Carroll Gardens" item-id="3488524" item-type="Rental" sitekey="6LcsCN8UAAAAABcTaJDzilIOyzXuLAtKafjcE051">
#    <div class="styled__ModalPin-sc-11rt3cv-0 bmPiHD">
#    </div>
#   </div>
#   <script defer="" type="text/javascript">
#    jQuery(function() {
#     var actionButtons = jQuery('.jsIsSaved, .jsNotSaved'),
#         buildingCondition = actionButtons.data('gtm-item-type') === 'Building',
#         userAgent = actionButtons.data('user-agent') === false;
#     if(buildingCondition || userAgent) {
#       actionButtons.removeClass('RealtyActions--small')
#     }
#     actionButtons.click( function() {
#       var $this = jQuery(this);
#       if (!$this.find('.jsIconHeart').length) {
#         if($this.hasClass('jsNotSaved')) {
#           $this.removeClass('jsNotSaved');
#           $this.addClass('jsIsSaved');
#           $this.addClass('RealtyActions--small');
#           $this.data('gtm-item-type') === 'Building' ? $this.removeClass('RealtyActions--small') : null;
#         } else {
#           $this.removeClass('jsIsSaved');
#           $this.addClass('jsNotSaved');
#           $this.removeClass('RealtyActions--small');
#         }
#       }
#     });
#   });
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/scripts/dynamic/advertising_resize-1da21f0484434d0b20f38d184081dca1c38956d9b55ff9687882f38c91a7955d.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/scripts/dynamic/home_tour-c5a5cf62c150e72f756f4944b746a5f742d8a7d240ea2198bc9c4fa218321a13.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/scripts/dynamic/similar_listings_slider-b71fa9af3b29925f4354a08d64b2027d36f8f0ccd4a409641bbc982d1008fe82.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/scripts/dynamic/save_button-5b57f6d777d2c5bffca5b95a9deb2a6cdad2fb84462290c4560c4d15766404cf.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/scripts/dynamic/toggle_expand_init-2d4cb6775869efd4b3509a6ef05cb1409cb4950989014aa5988382360cb21232.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/plugins/se_areaSelector-5b3eb453936a46f09572ad2e039c7c8482cd5f069809e8086773e2ed67482aba.js">
#   </script>
#   <script>
#    (function(document, SE) {
#         document.addEventListener("DOMContentLoaded", function () {
#           SE.MainNavList('  <div id=\"flash\" class=\"FlashMessage jsFlashMessage FlashMessage-error isError\">\n    <div id=\'flash_notice_inner\' class=\"FlashMessage-content FlashMessage-content--reset\">\n      \n      Please enter something to search for!\n    <\/div>\n    <button class=\"FlashMessage-close jsCloseFlash\">Close<\/button>\n  <\/div>\n  <script>\n  (function(\$) {\n    \$(\'[data-hide-on-flash=\"true\"]\').modal(\'hide\');\n  })(jQuery);\n  <\/script>\n');
#         });
#       })(document, SE)
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/pages/home/search_beds-44530735b932988810a880f9264094684f30f952e8c8a41bf78485290901b915.js">
#   </script>
#   <div aria-live="assertive" class="jsFlashMessageContainerWithAlertRole" role="alert">
#   </div>
#   <script type="text/javascript">
#    window.addEventListener('load', function() {
#     document.cookie = "google_one_tap=0;path=/;expires='N/A'"
#   });
#   </script>
#   <div data-site-key="6LcsCN8UAAAAABcTaJDzilIOyzXuLAtKafjcE051" id="authentication">
#    <div class="styled__AuthModalWrap-sc-16frzwi-4 cWeMlw">
#    </div>
#   </div>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/runtime-67d244317a0c2ec45347.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/framework-5fb9c39907ee01b61747.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/commons-d26df34c5fadd5271777.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/claimDealHDP-bffdb40b26f49edab172.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/lib-d5c3deb8-c7a1bd77c1cfd00dac12.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/shared-1c4c4404-93df4a639d0dc4d34946.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/shared-829bc818-dad96c42b20ccc067248.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/hdp-cdd053011af75bbec4bc.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/virtualOpenHouse-92452415af42c55982aa.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/shared-b482a680-4bcdbaa82193d98dbae9.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/rentalContactExperience-2250ce8a3ceb5bc8e935.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/styles-a6fda2e3c2c3b07af86f.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/shared-35b5364a-806fe04f0fbe68f9369c.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/map-16492deff8381540f488.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/addToCalendar-5b673f708f4a0c657263.chunk.js">
#   </script>
#   <iframe data-gtm-yt-inspected-289328_644="true" height="0" src="//8246315.fls.doubleclick.net/activityi;src=8246315;type=unive0;cat=allpa0;ord=3599788604088;gtm=2wg4l3;auiddc=2095183353.1620058760;~oref=https%3A%2F%2Fstreeteasy.com%2Fbuilding%2F556-court-street-brooklyn%2F2?" style="display: none; visibility: hidden;" width="0">
#   </iframe>
#   <iframe data-gtm-yt-inspected-289328_644="true" height="0" src="//8246315.fls.doubleclick.net/activityi;src=8246315;type=listi0;cat=renta0;ord=4238650235559;gtm=2wg4l3;auiddc=2095183353.1620058760;~oref=https%3A%2F%2Fstreeteasy.com%2Fbuilding%2F556-court-street-brooklyn%2F2?" style="display: none; visibility: hidden;" width="0">
#   </iframe>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/authentication-83559435a65af4e50742.chunk.js">
#   </script>
#   <script id="" type="text/javascript">
#    (function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"4017789"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&&"loaded"!==b&&"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");window.uetq.push({ec:"rentals_hdp",ea:"view",el:"rentals",ev:"0"});
#   </script>
#   <script id="" type="text/javascript">
#    (function(){function l(a,g,b,m,n,h,k,d,e){a.ZillowAnalyticsObject=b;a[b]=a[b]||[];if(!a[b].initialize&&!a[b].invoked)return a[b].invoked=1,a[b]._loadOptions=n,h="identify track page off on use unuse setdim event".split(" "),k=function(f){return function(){a[b].push([].concat(f,[].slice.call(arguments)));return a[b]}},h.forEach(function(f){a[b][f]=k(f)}),d=g.createElement("script"),e=g.getElementsByTagName("script")[0],d.async=!0,d.src=m,e&&e.parentNode.insertBefore(d,e),a[b]}var c=document&&document.location&&
# "streeteasy.com"===document.location.host;c=c?"se_prod_web":"se_dev_web";c={zillow:{apiKey:c,apiHost:"analytics.zg-api.com",secure:!0}};var p="//analytics.zg-api.com/a/s/js/v1/analytics.js";l(window,document,"zanalytics",p,c)})();google_tag_manager["GTM-MKTT9R"].macro(46)&&zanalytics.identify("undefined");zanalytics.setdim(google_tag_manager["GTM-MKTT9R"].macro(196));google_tag_manager["GTM-MKTT9R"].macro(197)?zanalytics.page({},{anonymousId:"45df6c12-127e-447f-b5a0-b7de7aa73cfb"}):zanalytics.page();
#   </script>
#   <script id="" type="text/javascript">
#    _uzactfeed=window._uzactfeed||[];_uzactfeed.push(["_setID","ED76A9551929EB11AA64DF5D6AB4A0EB"]);_uzactfeed.push(["_setSID","8DF29B31F103EB11AA66C3248CC4FC87"]);_uzactfeed.push(["_start"]);
# (function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.charset="utf-8";a.src=("https:"==document.location.protocol?"https://":"http://")+"cdn5.userzoom.com/feedback/js/uz_feed_us.js?cuid\x3d5FC691076FCDE41180C90050569444FB";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/save-65b91841f14a2c6d7fc1.chunk.js">
#   </script>
#   <script src="//cdn-assets-s3.streeteasy.com/assets/build/js/shareItem-5083ae49a1cbb2f786c6.chunk.js">
#   </script>
#   <!-- nyc main 94b708890c378319a8da8f72763021c6df37bce1 app-68fc6c476f-d5p7g -->
#   <div class="TooltipOverlay">
#   </div>
#   <script id="" type="text/javascript">
#    function setCookie(b,a,c){var d=google_tag_manager["GTM-MKTT9R"].macro(251);b=b+"\x3d"+a+"; path\x3d/; domain\x3d."+d.replace(/^www\./i,"");"undefined"!==typeof c&&(a=new Date,a.setTime(a.getTime()+864E5*c),b+="; expires\x3d"+a.toUTCString());document.cookie=b}setCookie("KruxPixel","true",3);
#   </script>
#   <img alt="" src="https://beacon.krxd.net/usermatch.gif?partner=streeteasy&amp;partner_uid=undefined" style="display:none"/>
#   <div style="display: none; visibility: hidden;">
#    <script type="text/javascript">
#     var _kiq=_kiq||[];(function(){setTimeout(function(){var a=document,b=a.getElementsByTagName("script")[0];a=a.createElement("script");a.type="text/javascript";a.async=!0;a.src="//s3.amazonaws.com/ki.js/51812/cvV.js";b.parentNode.insertBefore(a,b)},1)})();
#    </script>
#    <script charset="utf-8" type="text/javascript">
#     _kiq.push(["identify","undefined"]);
#    </script>
#    <script charset="utf-8" type="text/javascript">
#     _kiq.push(["set",{user_type:"anonymous",listing_type:"rental",building_id:"undefined","3d_tour":"undefined",listing_net_price:"undefined"}]);
#    </script>
#    <script type="text/javascript">
#     +function(a){a&&_kiq.push(["eventHandler","show",function(){a.ajax({url:"/_q"})}])}(window.jQuery);
#    </script>
#   </div>
#   <a aria-hidden="true" href="/building/556-court-street-brooklyn/2?_pxhc=1620058761246" rel="nofollow" style="width: 0px; height: 0px; line-height: 0; display: none;" tabindex="-1" target="_blank">
#   </a>
#   <div id="batBeacon525716380445" style="width:0px; height:0px; display:none; visibility:hidden;">
#    <img alt="" height="0" id="batBeacon11589586436" src="https://bat.bing.com/action/0?ti=4017789&amp;Ver=2&amp;mid=717a0162-59a9-4bbe-b609-1457b41da876&amp;sid=51ae0e70ac2b11eba67d8dae7fc0ad21&amp;vid=51ae5ba0ac2b11eb81424170741156d7&amp;vids=1&amp;pi=1200101525&amp;lg=en-US&amp;sw=1440&amp;sh=900&amp;sc=24&amp;tl=556%20Court%20Street%20%232%20in%20Carroll%20Gardens,%20Brooklyn%20%7C%20StreetEasy&amp;p=https%3A%2F%2Fstreeteasy.com%2Fbuilding%2F556-court-street-brooklyn%2F2&amp;r=&amp;lt=3725&amp;evt=pageLoad&amp;msclkid=N&amp;sv=1&amp;rn=649055" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/>
#    <img alt="" height="0" id="batBeacon384879085396" src="https://bat.bing.com/action/0?ti=4017789&amp;Ver=2&amp;mid=717a0162-59a9-4bbe-b609-1457b41da876&amp;sid=51ae0e70ac2b11eba67d8dae7fc0ad21&amp;vid=51ae5ba0ac2b11eb81424170741156d7&amp;vids=0&amp;ec=rentals_hdp&amp;ea=view&amp;el=rentals&amp;ev=0&amp;evt=custom&amp;msclkid=N&amp;rn=280275" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/>
#   </div>
#   <script charset="utf-16" src="https://cdn5.userzoom.com/voc/files/8DF29B31F103EB11AA66C3248CC4FC87/voc.js" type="text/javascript">
#   </script>
#   <iframe data-gtm-yt-inspected-289328_644="true" id="google_osd_static_frame_3873321542492" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;">
#   </iframe>
#   <iframe data-gtm-yt-inspected-289328_644="true" id="qualaroo_dnt_frame" src="//dntcl.qualaroo.com/frame.html" style="width: 1px; height: 1px; display: none; opacity: 0;">
#   </iframe>
#   <script id="" type="text/javascript">
#    function trackEvent(a,b,c){window&&window.zanalytics&&zanalytics.track("event",{action:b,category:a,label:c})}trackEvent(google_tag_manager["GTM-MKTT9R"].macro(303),google_tag_manager["GTM-MKTT9R"].macro(304),google_tag_manager["GTM-MKTT9R"].macro(305));
#   </script>
#  </body>
# </html>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price = soup.find(class_ = "price").text.strip()
print(price)
# Out:
# $2,800
#                 for rent

# %%
price.split()
# Out:
# ['$2,800', 'for', 'rent']

# %%
price = price.split()[0]
price
# Out:
# '$2,800'

# %%
all_details = soup.find_all(class_ = "detail_cell")
all_details
# Out:
# [<span class="detail_cell first_detail_cell">1,100 ft²</span>,
#  <span class="detail_cell">$30 per ft²</span>,
#  <span class="detail_cell">6 rooms</span>,
#  <span class="detail_cell">3 beds</span>,
#  <span class="detail_cell last_detail_cell">1 bath</span>]

# %%
sq_ft = int(all_details[0].text.split()[0].replace(',', ''))
cost_per_sq_ft = all_details[1].text
num_rooms = int(all_details[2].text.split()[0])
num_beds = int(all_details[3].text.split()[0])
num_baths = int(all_details[4].text.split()[0])
print(sq_ft, cost_per_sq_ft, num_rooms, num_beds, num_baths, sep = ", ")
# Out:
# 1100, $30 per ft², 6, 3, 1

# %%
address_raw = soup.find(class_ = "backend_data BuildingInfo-item").find_all(class_ = "Text")
address_raw
# Out:
# [<a class="Text" href="https://streeteasy.com/building/556-court-street-brooklyn"> 556 Court Street</a>,
#  <span class="Text">
#               Brooklyn, NY 11231
#            </span>]

# %%
address = address_raw[0].text.strip() + ", " + address_raw[1].text.strip()
print(address)
# Out:
# 556 Court Street, Brooklyn, NY 11231

# %%
zip_code = int(address.split()[-1])
zip_code
# Out:
# 11231

# %%
street_address = address.split(",")[0]
street_address
# Out:
# '556 Court Street'

# %%
unit = soup.find(class_ = "building-title").a.text.split()[-1]
unit
# Out:
# '#2'

# %%
import pandas as pd
import pickle

# %%
df_headers = ["address", "zip code", "unit", "rent", "size (sq. ft)", "rooms", "beds", "baths", "has a studio", "link"]

apt_data = []
index = 0
apt_dict = dict(zip(df_headers, [street_address, zip_code, unit, price, sq_ft, num_rooms, num_beds, num_baths, link]))
apt_data.append(apt_dict)
apt_data
# Out:
# [{'address': '1296 Pacific Street',
#   'zip code': 11216,
#   'unit': '#608',
#   'rent': '$1,475',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 0,
#   'baths': 1.0,
#   'has a studio': 'https://streeteasy.com/building/61-south-elliott-place-brooklyn/c'}]

# %%
test_frame = pd.DataFrame.from_dict(apt_data)
test_frame
# Out:
#             address  zip code unit    rent  size (sq. ft)  rooms  beds  baths
# 0  556 Court Street     11231   #2  $2,800           1100      6     3      1

# %%
#want to scrape every apartment listing on a page (other than the first 2 "featured" listings, which could cause duplicates)
page_num = 1
scraping_url = f"https://streeteasy.com/for-rent/brooklyn?page={page_num}"
driver.get(scraping_url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
all_urls = soup.find_all('a', class_ = "listingCard-globalLink jsGlobalListingCardLink", attrs = "href")
print(all_urls)
# Out:
# [<a aria-labelledby="info-3509564" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509564" data-slot="0" href="https://streeteasy.com/building/1809-albemarle-road-brooklyn/c49"></a>, <a aria-labelledby="info-3509561" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509561" data-slot="0" href="https://streeteasy.com/building/287-lefferts-avenue-brooklyn/1"></a>, <a aria-labelledby="info-3509560" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509560" data-slot="0" href="https://streeteasy.com/rental/3509560"></a>, <a aria-labelledby="info-3509559" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509559" data-slot="0" href="https://streeteasy.com/building/748-st-marks-avenue-brooklyn/6c"></a>, <a aria-labelledby="info-3509554" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509554" data-slot="0" href="https://streeteasy.com/building/the-landing-at-brooklyn-bridge-park/5f"></a>, <a aria-labelledby="info-3509532" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509532" data-slot="0" href="https://streeteasy.com/building/580-decatur-street-brooklyn/garden"></a>, <a aria-labelledby="info-3509531" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509531" data-slot="0" href="https://streeteasy.com/building/178-carlton-avenue-brooklyn/2"></a>, <a aria-labelledby="info-3509530" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509530" data-slot="0" href="https://streeteasy.com/building/1340-hancock-street-brooklyn/3r"></a>, <a aria-labelledby="info-3509524" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509524" data-slot="0" href="https://streeteasy.com/building/102-quincy-street-brooklyn/4r"></a>, <a aria-labelledby="info-3509519" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509519" data-slot="0" href="https://streeteasy.com/building/2837-church-avenue-brooklyn/2r"></a>, <a aria-labelledby="info-3509511" class="listingCard-globalLink jsGlobalListingCardLink" data-category="rentals_search" data-listing-id="3509511" data-slot="0" href="https://streeteasy.com/building/1296-pacific-street-brooklyn/608"></a>]

# %%
listings = []
for u in all_urls:
    link = u.get("href")
    listings.append(link)
print(listings)
# Out:
# ['https://streeteasy.com/building/1809-albemarle-road-brooklyn/c49', 'https://streeteasy.com/building/287-lefferts-avenue-brooklyn/1', 'https://streeteasy.com/rental/3509560', 'https://streeteasy.com/building/748-st-marks-avenue-brooklyn/6c', 'https://streeteasy.com/building/the-landing-at-brooklyn-bridge-park/5f', 'https://streeteasy.com/building/580-decatur-street-brooklyn/garden', 'https://streeteasy.com/building/178-carlton-avenue-brooklyn/2', 'https://streeteasy.com/building/1340-hancock-street-brooklyn/3r', 'https://streeteasy.com/building/102-quincy-street-brooklyn/4r', 'https://streeteasy.com/building/2837-church-avenue-brooklyn/2r', 'https://streeteasy.com/building/1296-pacific-street-brooklyn/608']

# %%
len(listings)
# Out:
# 11

# %%
def parse_details(details_list, sq_ft = -1, cost_per_sq_ft = -1, num_rooms = -1, num_beds = -1, num_baths = -1, has_studio = 0):
    for d in details_list:
        print("parsing: " + d.text)
        if d.text == "studio":
            num_beds = 0
            has_studio = 1
        else:
            keyword = (d.text.split()[1])
            print("keyword: " + keyword)
            if keyword == "ft²":
                sq_ft = int(d.text.split()[0].replace(',', ''))

            elif keyword == "per":
                cost_per_sq_ft = d.text

            elif keyword in ["room", "rooms"]:
                num_rooms = float(d.text.split()[0])
                print(str(num_rooms) + " rooms")

            elif keyword in ["bed", "beds"]:
                num_beds = float(d.text.split()[0])
                
            elif keyword in ["bath", "baths"]:
                num_baths = float(d.text.split()[0]) #sometimes there are half-bathrooms
    return([sq_ft, cost_per_sq_ft, num_rooms, num_beds, num_baths, has_studio])

# %%
parse_details(all_details)
# Out:
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: studio
# parsing: 1 bath
# keyword: bath
# [-1, -1, 3.0, 0, 1.0, 1]

# %%
all_details
# Out:
# [<span class="detail_cell first_detail_cell">4 rooms</span>,
#  <span class="detail_cell">2 beds</span>,
#  <span class="detail_cell last_detail_cell">1 bath</span>]

# %%
apt_data = []

#driver = webdriver.Chrome(chromedriver)

def scrape_page(listings):
    for l in listings:
        driver.get(l)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        address_raw = soup.find(class_ = "backend_data BuildingInfo-item").find_all(class_ = "Text")
        address = address_raw[0].text.strip() + ", " + address_raw[1].text.strip()
        street_address = address.split(",")[0]
        unit = soup.find(class_ = "building-title").a.text.split()[-1]
        zip_code = int(address.split()[-1])
        price = soup.find(class_ = "price").text.split()[0]
        all_details = soup.find_all(class_ = "detail_cell")
        [sq_ft, cost_per_sq_ft, num_rooms, num_beds, num_baths, has_studio] = parse_details(all_details)
        apt_dict = dict(zip(df_headers, [street_address, zip_code, unit, price, sq_ft, num_rooms, num_beds, num_baths, has_studio, l]))
        apt_data.append(apt_dict)
        #sq_ft = num_rooms = num_beds = num_baths = -1
        time.sleep(random.randint(1, 4)) # waiting 5 seconds every time triggered a captcha quickly, but this doesn't

# %%
apt_data
# Out:
# [{'address': '1296 Pacific Street',
#   'zip code': 11216,
#   'unit': '#608',
#   'rent': '$1,475',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 0,
#   'baths': 1.0},
#  {'address': '227 Kingston Avenue',
#   'zip code': 11213,
#   'unit': '#2FF',
#   'rent': '$1,895',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 1,
#   'baths': 1.0},
#  {'address': '227 Kingston Avenue',
#   'zip code': 11213,
#   'unit': '#2FF',
#   'rent': '$1,895',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 1,
#   'baths': 1.0},
#  {'address': '272 Albany Avenue',
#   'zip code': 11213,
#   'unit': '#F3',
#   'rent': '$1,650',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 1,
#   'baths': 1.0},
#  {'address': '218 Hawthorne Street',
#   'zip code': 11225,
#   'unit': '#2A',
#   'rent': '$1,800',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 1,
#   'baths': 1.0},
#  {'address': '31 Brooklyn Avenue',
#   'zip code': 11216,
#   'unit': '#2H',
#   'rent': '$2,550',
#   'size (sq. ft)': -1,
#   'rooms': 5,
#   'beds': 2,
#   'baths': 1.0},
#  {'address': '115 South 2nd Street',
#   'zip code': 11249,
#   'unit': '#2AA1',
#   'rent': '$3,800',
#   'size (sq. ft)': -1,
#   'rooms': 4,
#   'beds': 3,
#   'baths': 1.0},
#  {'address': '533 Washington Avenue',
#   'zip code': 11238,
#   'unit': '#3B',
#   'rent': '$1,900',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 1,
#   'baths': 1.0},
#  {'address': '1710 Quentin Road',
#   'zip code': 11229,
#   'unit': '#405F',
#   'rent': '$2,399',
#   'size (sq. ft)': 1050,
#   'rooms': 17,
#   'beds': 3,
#   'baths': 2.0},
#  {'address': '148 Hancock Street',
#   'zip code': 11216,
#   'unit': '#4B',
#   'rent': '$1,820',
#   'size (sq. ft)': -1,
#   'rooms': 3,
#   'beds': 1,
#   'baths': 1.0},
#  {'address': '250 Lenox Road',
#   'zip code': 11226,
#   'unit': '#5B',
#   'rent': '$2,500',
#   'size (sq. ft)': -1,
#   'rooms': 6,
#   'beds': 2,
#   'baths': 2.0},
#  {'address': '106 Ellery Street',
#   'zip code': 11206,
#   'unit': '#1A',
#   'rent': '$3,499',
#   'size (sq. ft)': -1,
#   'rooms': 5,
#   'beds': 4,
#   'baths': 2.0},
#  {'address': '211 Boerum Street',
#   'zip code': 11206,
#   'unit': '#2',
#   'rent': '$2,600',
#   'size (sq. ft)': -1,
#   'rooms': 5,
#   'beds': 2,
#   'baths': 3.0}]

# %%
test_frame = pd.DataFrame.from_dict(apt_data)
test_frame
# Out:
#                                               address  zip code     unit  \
# 0                                 1809 Albemarle Road     11226     #C49
# 1                                 287 Lefferts Avenue     11225       #1
# 2                                     285 23rd Street     11215   Street
# 3                             748 Saint Mark's Avenue     11216      #6C
# 4   The Landing At Brooklyn Bridge Park 15 Bridge ...     11201      #5F
# 5                                  580 Decatur Street     11233  #GARDEN
# 6                                  178 Carlton Avenue     11205       #2
# 7                                 1340 Hancock Street     11237      #3R
# 8                                   102 Quincy Street     11238      #4R
# 9                                  2837 Church Avenue     11226      #2R
# 10                                1296 Pacific Street     11216     #608
#
#       rent  size (sq. ft)  rooms  beds  baths
# 0   $2,150             -1      4     2    1.0
# 1   $4,000           1800      5     2    2.0
# 2   $1,900             -1      4     2    1.0
# 3   $1,695             -1      4     1    1.0
# 4   $2,307             -1      1     0    1.0
# 5   $2,950             -1      5     1    1.0
# 6   $2,500           1200      3     1    1.0
# 7   $2,750             -1      5     3    1.0
# 8   $2,900             -1      4     2    1.5
# 9   $2,300             -1      3     1    1.0
# 10  $1,475             -1      3     0    1.0

# %% [markdown]
# From this limited sample, it appears that most listings don't include floor size, so it likely won'e be used in the regression.
#
# Regardless, every time I finish scraping a page of listings, I'll pickle the dataframe (in case there's a runtime error).

# %%
test_frame.to_pickle(f"data/apartement_data_{page_num}.pickle")

# %%
page_num = 1
pickle_frame = pd.read_pickle(f"data/apartement_data_{page_num}.pickle")
pickle_frame
# Out:
#                                               address  zip code     unit  \
# 0                                 1809 Albemarle Road     11226     #C49
# 1                                 287 Lefferts Avenue     11225       #1
# 2                                     285 23rd Street     11215   Street
# 3                             748 Saint Mark's Avenue     11216      #6C
# 4   The Landing At Brooklyn Bridge Park 15 Bridge ...     11201      #5F
# 5                                  580 Decatur Street     11233  #GARDEN
# 6                                  178 Carlton Avenue     11205       #2
# 7                                 1340 Hancock Street     11237      #3R
# 8                                   102 Quincy Street     11238      #4R
# 9                                  2837 Church Avenue     11226      #2R
# 10                                1296 Pacific Street     11216     #608
#
#       rent  size (sq. ft)  rooms  beds  baths
# 0   $2,150             -1      4     2    1.0
# 1   $4,000           1800      5     2    2.0
# 2   $1,900             -1      4     2    1.0
# 3   $1,695             -1      4     1    1.0
# 4   $2,307             -1      1     0    1.0
# 5   $2,950             -1      5     1    1.0
# 6   $2,500           1200      3     1    1.0
# 7   $2,750             -1      5     3    1.0
# 8   $2,900             -1      4     2    1.5
# 9   $2,300             -1      3     1    1.0
# 10  $1,475             -1      3     0    1.0

# %%
# Also want to find number of days on market
all_vitals = soup.find_all(class_ = "Vitals-data")
#print(all_vitals)
all_vitals[0].text.strip()
# Out:
# 'Available Now'

# %%
def parse_vitals(vitals_list, avail_date, list_date, price_change):
    v = vitals_list[0].text.strip()
    if v == "Available Now": avail_date

# %%
listings = []

driver = webdriver.Chrome(chromedriver)

for page_num in range(1, 11):
    scraping_url = f"https://streeteasy.com/for-rent/brooklyn?page={page_num}"
    driver.get(scraping_url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    all_urls = soup.find_all('a', class_ = "listingCard-globalLink jsGlobalListingCardLink", attrs = "href")
    for u in all_urls:
        link = u.get("href")
        listings.append(link)
    time.sleep(random.randint(5, 10))
    
print(listings)
# Out:
# ['https://streeteasy.com/building/227-kingston-avenue-brooklyn/2ff', 'https://streeteasy.com/building/272-albany-avenue-brooklyn/f3', 'https://streeteasy.com/building/218-hawthorne-street-brooklyn/2a', 'https://streeteasy.com/building/31-brooklyn-avenue-brooklyn/2h', 'https://streeteasy.com/building/115-south-2-street-brooklyn/2aa1', 'https://streeteasy.com/building/533-washington-avenue-brooklyn/3b', 'https://streeteasy.com/building/1710-quentin-road-brooklyn/405f', 'https://streeteasy.com/building/148-hancock-street-brooklyn/4b', 'https://streeteasy.com/building/250-lenox-road-brooklyn/5b', 'https://streeteasy.com/building/106-ellery-street-brooklyn/1a', 'https://streeteasy.com/building/211-boerum-street-brooklyn/2', 'https://streeteasy.com/building/211-boerum-street-brooklyn/4', 'https://streeteasy.com/building/106-central-avenue-brooklyn/3c1', 'https://streeteasy.com/building/360-central-avenue-brooklyn/2l', 'https://streeteasy.com/building/161-avenue-p-brooklyn/4', 'https://streeteasy.com/building/181-east-32-street-brooklyn/2b', 'https://streeteasy.com/building/946-bushwick-avenue-brooklyn/508', 'https://streeteasy.com/building/569-4-avenue-brooklyn/1106', 'https://streeteasy.com/building/810-lexington-avenue-brooklyn/6a', 'https://streeteasy.com/building/ridgewood-lodge-no-710-free-and-a/3d2', 'https://streeteasy.com/building/406-cornelia-street-brooklyn/b2', 'https://streeteasy.com/building/1503-jefferson-avenue-brooklyn/rental/3510835', 'https://streeteasy.com/building/1749-stillwell-avenue-brooklyn/2b', 'https://streeteasy.com/building/1236-halsey-street-brooklyn/garden', 'https://streeteasy.com/building/1044-bedford-avenue-brooklyn/6c', 'https://streeteasy.com/building/72-box-street-brooklyn/4cl', 'https://streeteasy.com/building/ridgewood-lodge-no-710-free-and-a/3gg1', 'https://streeteasy.com/building/91-stockton-street-brooklyn/3b', 'https://streeteasy.com/building/64-himrod-street-brooklyn/3r', 'https://streeteasy.com/building/3000-ocean-parkway-brooklyn/23c', 'https://streeteasy.com/building/716-knickerbocker-avenue-brooklyn/1', 'https://streeteasy.com/building/1145-greene-avenue-brooklyn/4e', 'https://streeteasy.com/building/2901-avenue-i-brooklyn/5f', 'https://streeteasy.com/building/94-5-avenue-brooklyn/1r', 'https://streeteasy.com/building/1296-nostrand-avenue-brooklyn/2a', 'https://streeteasy.com/building/358-macon-street-brooklyn/2', 'https://streeteasy.com/building/92-pulaski-street-brooklyn/2r', 'https://streeteasy.com/building/233-south-4-street-brooklyn/d', 'https://streeteasy.com/building/8101-5-avenue-brooklyn/3', 'https://streeteasy.com/building/34-butler-place-brooklyn/21', 'https://streeteasy.com/building/984-52-street-brooklyn/4f', 'https://streeteasy.com/building/237-11-street-brooklyn/5j', 'https://streeteasy.com/building/111-5-avenue-brooklyn/1r', 'https://streeteasy.com/building/569-4-avenue-brooklyn/810', 'https://streeteasy.com/building/237-11-street-brooklyn/7f', 'https://streeteasy.com/building/8321-3-avenue-brooklyn/d', 'https://streeteasy.com/building/3124-avenue-i-brooklyn/5', 'https://streeteasy.com/building/806-bergen-street-brooklyn/1c', 'https://streeteasy.com/building/3208-glenwood-road-brooklyn/5a', 'https://streeteasy.com/building/1693-grove-street-ridgewood/2f', 'https://streeteasy.com/building/1005-atlantic-avenue-brooklyn/5da', 'https://streeteasy.com/building/180-lenox-road-brooklyn/1j', 'https://streeteasy.com/building/237-11-street-brooklyn/6c', 'https://streeteasy.com/building/236-north-11-street-brooklyn/2b', 'https://streeteasy.com/building/1235-halsey-street-brooklyn/a3', 'https://streeteasy.com/building/78-ryerson-street-brooklyn/1a', 'https://streeteasy.com/building/356-maple-street-brooklyn/unit-c7', 'https://streeteasy.com/building/5-westminster-road-brooklyn/a4', 'https://streeteasy.com/building/1348-ocean-avenue-brooklyn/5g', 'https://streeteasy.com/building/584-franklin-avenue-brooklyn/1ac', 'https://streeteasy.com/building/1519-albemarle-road-brooklyn/apt2b', ' ...

# %%
driver = webdriver.Chrome(chromedriver)
scrape_page(listings)
# Out:
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 5 rooms
# keyword: rooms
# 5.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 1 bath
# keyword: bath
# parsing: 4 rooms
# keyword: rooms
# 4.0 rooms
# parsing: 3 beds
# keyword: beds
# parsing: 1 bath
# keyword: bath
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 1,050 ft²
# keyword: ft²
# parsing: $27 per ft²
# keyword: per
# parsing: 17 rooms
# keyword: rooms
# 17.0 rooms
# parsing: 3 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 6 rooms
# keyword: rooms
# 6.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 5 rooms
# keyword: rooms
# 5.0 rooms
# parsing: 4 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 5 rooms
# keyword: rooms
# 5.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 3 baths
# keyword: baths
# parsing: 7 rooms
# keyword: rooms
# 7.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 4 baths
# keyword: baths
# parsing: 4 rooms
# keyword: rooms
# 4.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 5 rooms
# keyword: rooms
# 5.0 rooms
# parsing: 3 beds
# keyword: beds
# parsing: 1 bath
# keyword: bath
# parsing: 2 rooms
# keyword: rooms
# 2.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 4 rooms
# keyword: rooms
# 4.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 4 rooms
# keyword: rooms
# 4.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 4 rooms
# keyword: rooms
# 4.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 7 rooms
# keyword: rooms
# 7.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 4 rooms
# keyword: rooms
# 4.0 rooms
# parsing: 3 beds
# keyword: beds
# parsing: 1 bath
# keyword: bath
# parsing: 6 rooms
# keyword: rooms
# 6.0 rooms
# parsing: 3 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 2 rooms
# keyword: rooms
# 2.0 rooms
# parsing: studio
# parsing: 1 bath
# keyword: bath
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 2 beds
# keyword: beds
# parsing: 1 bath
# keyword: bath
# parsing: 5 rooms
# keyword: rooms
# 5.0 rooms
# parsing: 4 beds
# keyword: beds
# parsing: 2 baths
# keyword: baths
# parsing: 3 rooms
# keyword: rooms
# 3.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1 bath
# keyword: bath
# parsing: 650 ft²
# keyword: ft²
# parsing: $53 per ft²
# keyword: per
# parsing: 1 room
# keyword: room
# 1.0 rooms
# parsing: 1 bed
# keyword: bed
# parsing: 1+ bath
# keyword: bath
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-a3093414e99b> in <module>
#       1 driver = webdriver.Chrome(chromedriver)
# ----> 2 scrape_page(listings)
#
# <ipython-input-242-5ebe369c5992> in scrape_page(listings)
#      14         price = soup.find(class_ = "price").text.split()[0]
#      15         all_details = soup.find_all(class_ = "detail_cell")
# ---> 16         [sq_ft, cost_per_sq_ft, num_rooms, num_beds, num_baths, has_studio] = parse_details(all_details)
#      17         apt_dict = dict(zip(df_headers, [street_address, zip_code, unit, price, sq_ft, num_rooms, num_beds, num_baths, has_studio, l]))
#      18         apt_data.append(apt_dict)
#
# <ipython-input-240-193489cdcf70> in parse_details(details_list, sq_ft, cost_per_sq_ft, num_rooms, num_beds, num_baths, has_studio)
#      22
#      23             elif keyword in ["bath", "baths"]:
# ---> 24                 num_baths = float(d.text.split()[0]) #sometimes there are half-bathrooms
#      25     return([sq_ft, cost_per_sq_ft, num_rooms, num_beds, num_baths, has_studio])
#
# ValueError: could not convert string to float: '1+'

# %%
print(apt_data)
# Out:
# [{'address': '227 Kingston Avenue', 'zip code': 11213, 'unit': '#2FF', 'rent': '$1,895', 'size (sq. ft)': -1, 'rooms': 3, 'beds': 1, 'baths': 1.0, 'link': 'https://streeteasy.com/building/227-kingston-avenue-brooklyn/2ff'}, {'address': '272 Albany Avenue', 'zip code': 11213, 'unit': '#F3', 'rent': '$1,650', 'size (sq. ft)': -1, 'rooms': 3, 'beds': 1, 'baths': 1.0, 'link': 'https://streeteasy.com/building/272-albany-avenue-brooklyn/f3'}, {'address': '218 Hawthorne Street', 'zip code': 11225, 'unit': '#2A', 'rent': '$1,800', 'size (sq. ft)': -1, 'rooms': 3, 'beds': 1, 'baths': 1.0, 'link': 'https://streeteasy.com/building/218-hawthorne-street-brooklyn/2a'}, {'address': '31 Brooklyn Avenue', 'zip code': 11216, 'unit': '#2H', 'rent': '$2,550', 'size (sq. ft)': -1, 'rooms': 5, 'beds': 2, 'baths': 1.0, 'link': 'https://streeteasy.com/building/31-brooklyn-avenue-brooklyn/2h'}, {'address': '115 South 2nd Street', 'zip code': 11249, 'unit': '#2AA1', 'rent': '$3,800', 'size (sq. ft)': -1, 'rooms': 4, 'beds': 3, 'baths': 1.0, 'link': 'https://streeteasy.com/building/115-south-2-street-brooklyn/2aa1'}, {'address': '533 Washington Avenue', 'zip code': 11238, 'unit': '#3B', 'rent': '$1,900', 'size (sq. ft)': -1, 'rooms': 3, 'beds': 1, 'baths': 1.0, 'link': 'https://streeteasy.com/building/533-washington-avenue-brooklyn/3b'}, {'address': '1710 Quentin Road', 'zip code': 11229, 'unit': '#405F', 'rent': '$2,399', 'size (sq. ft)': 1050, 'rooms': 17, 'beds': 3, 'baths': 2.0, 'link': 'https://streeteasy.com/building/1710-quentin-road-brooklyn/405f'}, {'address': '148 Hancock Street', 'zip code': 11216, 'unit': '#4B', 'rent': '$1,820', 'size (sq. ft)': -1, 'rooms': 3, 'beds': 1, 'baths': 1.0, 'link': 'https://streeteasy.com/building/148-hancock-street-brooklyn/4b'}, {'address': '250 Lenox Road', 'zip code': 11226, 'unit': '#5B', 'rent': '$2,500', 'size (sq. ft)': -1, 'rooms': 6, 'beds': 2, 'baths': 2.0, 'link': 'https://streeteasy.com/building/250-lenox-road-brooklyn/5b'}, {'address': '106 Ellery Street', 'zip code': 11206, 'unit': '#1A', 'rent': '$3,499', 'size (sq. ft)': -1, 'rooms': 5, 'beds': 4, 'baths': 2.0, 'link': 'https://streeteasy.com/building/106-ellery-street-brooklyn/1a'}, {'address': '211 Boerum Street', 'zip code': 11206, 'unit': '#2', 'rent': '$2,600', 'size (sq. ft)': -1, 'rooms': 5, 'beds': 2, 'baths': 3.0, 'link': 'https://streeteasy.com/building/211-boerum-street-brooklyn/2'}]

# %%
new_test_frame = pd.DataFrame.from_dict(apt_data)
new_test_frame
# Out:
#                     address  zip code     unit    rent  size (sq. ft)  rooms  \
# 0       1296 Pacific Street     11216     #608  $1,475             -1    3.0
# 1       227 Kingston Avenue     11213     #2FF  $1,895             -1    3.0
# 2         272 Albany Avenue     11213      #F3  $1,650             -1    3.0
# 3      218 Hawthorne Street     11225      #2A  $1,800             -1    3.0
# 4        31 Brooklyn Avenue     11216      #2H  $2,550             -1    5.0
# 5      115 South 2nd Street     11249    #2AA1  $3,800             -1    4.0
# 6     533 Washington Avenue     11238      #3B  $1,900             -1    3.0
# 7         1710 Quentin Road     11229    #405F  $2,399           1050   17.0
# 8        148 Hancock Street     11216      #4B  $1,820             -1    3.0
# 9            250 Lenox Road     11226      #5B  $2,500             -1    6.0
# 10        106 Ellery Street     11206      #1A  $3,499             -1    5.0
# 11        211 Boerum Street     11206       #2  $2,600             -1    5.0
# 12        211 Boerum Street     11206       #4  $2,995             -1    7.0
# 13       106 Central Avenue     11206     #3C1  $1,900             -1    4.0
# 14       360 Central Avenue     11221      #2L  $2,500             -1    5.0
# 15             161 Avenue P     11204       #4  $1,575             -1    2.0
# 16     181 East 32nd Street     11226      #2B  $1,650             -1    4.0
# 17      946 Bushwick Avenue     11221     #508  $2,800             -1    4.0
# 18        569 Fourth Avenue     11215    #1106  $3,150             -1    4.0
# 19     810 Lexington Avenue     11221      #6A  $3,000             -1    7.0
# 20  Ridgewood Lodge No. 710     11221     #3D2  $2,999             -1    4.0
# 21      406 Cornelia Street     11237      #B2  $2,700             -1    6.0
# 22    1503 Jefferson Avenue     11237      #5A  $1,900             -1    2.0
# 23    1749 Stillwell Avenue     11223      #2B  $1,850             -1    3.0
# 24       1236 Halsey Street     11207  #GARDEN  $3,999             -1    5.0
# 25      1044 Bedford Avenue     11205      #6C  $2,950             -1    3.0
#
#     beds  baths                                       has a studio  \
# 0    0.0    1.0  https://streeteasy.com/building/61-south-ellio...
# 1    1.0    1.0                                                  0
# 2    1.0    1.0                                                  0
# 3    1.0    1.0                                                  0
# 4    2.0    1.0                                                  0
# 5    3.0    1.0                                                  0
# 6    1.0    1.0                                                  0
# 7    3.0    2.0                                                  0
# 8    1.0    1.0                                                  0
# 9    2.0    2.0                                                  0
# 10   4.0    2.0                                                  0
# 11   2.0    3.0                                                  0
# 12   2.0    4.0                                                  0
# 13   1.0    1.0                                                  0
# 14   3.0    1.0                                                  0
# 15   1.0    1.0                                                  0
# 16   1.0    1.0                                                  0
# 17   2.0    2.0                                                  0
# 18   1.0    1.0                                                  0
# 19   2.0    2.0                                                  0
# 20   3.0    1.0                                                  0
# 21   3.0    2.0                                                  0
# 22   0.0    1.0                                                  1
# 23   2.0    1.0                                                  0
# 24   4.0    2.0                                                  0
# 25   1.0    1.0                                                  0
#
#                                                  link
# 0                                                 NaN
# 1   https://streeteasy.com/building/227-kingston-a...
# 2   https://streeteasy.com/building/272-albany-ave...
# 3   https://streeteasy.com/building/218-hawthorne-...
# 4   https://streeteasy.com/building/31-brooklyn-av...
# 5   https://streeteasy.com/building/115-south-2-st...
# 6   https://streeteasy.com/building/533-washington...
# 7   https://streeteasy.com/building/1710-quentin-r...
# 8   https://streeteasy.com/building/148-hancock-st...
# 9   https://streeteasy.com/building/250-lenox-road...
# 10  https://streeteasy.com/building/106-ellery-str...
# 11  https://streeteasy.com/building/211-boerum-str...
# 12  https://streeteasy.com/building/211-boerum-str...
# 13  https://streeteasy.com/building/106-central-av...
# 14  https://streeteasy.com/building/360-central-av...
# 15  https://streeteasy.com/building/161-avenue-p-b...
# 16  https://streeteasy.com/building/181-east-32-st...
# 17  https://streeteasy.com/building/946-bushwick-a...
# 18  https://streeteasy.com/building/569-4-avenue-b...
# 19  https://streeteasy.com/building/810-lexington-...
# 20  https://streeteasy.com/building/ridgewood-lodg...
# 21  https://streeteasy.com/building/406-cornelia-s...
# 22  https://streeteasy.com/building/1503-jefferson...
# 23  https://streeteasy.com/building/1749-stillwell...
# 24  https://streeteasy.com/building/1236-halsey-st...
# 25  https://streeteasy.com/building/1044-bedford-a...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# source: https://streeteasy.com/blog/apartment-amenities-new-yorkers-want-most/

# %%
driver = webdriver.Chrome(chromedriver)
driver.get("https://streeteasy.com/building/state-renaissance-court/406")
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()

# %%
import re

# %%
#a_list = soup.find_all("li", attrs = {"class": "AmenitiesBlock-item"})
a_list = soup.find_all("li", attrs = {"class": re.compile("^AmenitiesBlock\-.*[iI]tem$")})
a_list
# Out:
# [<li class="AmenitiesBlock-highlightsItem">
#  <div class="AmenitiesBlock-highlightsIconBox">
#  <span class="AmenitiesBlock-highlightsIcon AmenitiesBlock-highlightsIcon--doorman"></span>
#  </div>
#  <div class="AmenitiesBlock-highlightsLabel">
#  <div class="Text">
#                    Doorman
#                  </div>
#  </div>
#  </li>,
#  <li class="AmenitiesBlock-highlightsItem">
#  <div class="AmenitiesBlock-highlightsIconBox">
#  <span class="AmenitiesBlock-highlightsIcon AmenitiesBlock-highlightsIcon--elevator"></span>
#  </div>
#  <div class="AmenitiesBlock-highlightsLabel">
#  <div class="Text">
#                    Elevator
#                  </div>
#  </div>
#  </li>,
#  <li class="AmenitiesBlock-highlightsItem">
#  <div class="AmenitiesBlock-highlightsIconBox">
#  <span class="AmenitiesBlock-highlightsIcon AmenitiesBlock-highlightsIcon--pets"></span>
#  </div>
#  <div class="AmenitiesBlock-highlightsLabel">
#  <div class="Text">
#                    Pets Allowed
#                  </div>
#  </div>
#  </li>,
#  <li class="AmenitiesBlock-item">
#                    Bike Room
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Garage Parking
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Gym
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Laundry in Building
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Live-in Super
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Locker/Cage
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Smoke-free
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Wheelchair Access
#                </li>,
#  <li class="AmenitiesBlock-item">
#  </li>,
#  <li class="AmenitiesBlock-item">
#  <div class="" data-google-query-id="CJuY_Ku7tfACFQAKiAkdSjgG9w" id="rtt_main_p1" style="zoom: 1; opacity: 1; min-width: 109px; min-height: 25px;">
#  <div id="google_ads_iframe_/7449/Streeteasy/property_details/rent_general/rtt_main_p1_0__container__" style="border: 0pt none; display: inline-block; width: 100%; height: auto;"><iframe data-google-container-id="1" data-gtm-yt-inspected-289328_644="true" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="22" id="google_ads_iframe_/7449/Streeteasy/property_details/rent_general/rtt_main_p1_0" loading="eager" marginheight="0" marginwidth="0" name="" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://24a9321a2d0da6542a2bc8bfbdfaca5d.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="border: 0px; vertical-align: bottom; min-width: 100%;" title="3rd party ad content" width="0"></iframe></div></div>
#  </li>,
#  <li class="AmenitiesBlock-item">
#                    City View
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Dishwasher
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Hardwood Floors
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Courtyard
#                </li>,
#  <li class="AmenitiesBlock-item">
#                    Garden
#                </li>]

# %%
amenities = []
for a in a_list:
    amenities.append(a.text.strip())
amenities = list(filter(None, amenities))
amenities
# Out:
# ['Doorman',
#  'Elevator',
#  'Pets Allowed',
#  'Bike Room',
#  'Garage Parking',
#  'Gym',
#  'Laundry in Building',
#  'Live-in Super',
#  'Locker/Cage',
#  'Smoke-free',
#  'Wheelchair Access',
#  'City View',
#  'Dishwasher',
#  'Hardwood Floors',
#  'Courtyard',
#  'Garden']

# %%
# Out:
# 32
